# %% [markdown]
# # LSTM Travel Time Prediction - N103.2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
traffic = pd.read_csv('../db.csv', parse_dates = ["timeStamp"])
traffic.head(10)
# Out:
#    currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# 0            64             64                 21                  21
# 1            34             43                 49                  39
# 2            64             64                 21                  21
# 3            51             51                 37                  37
# 4            74             74                 21                  21
# 5            33             43                 51                  39
# 6            64             64                 21                  21
# 7            39             50                 49                  38
# 8            74             74                 21                  21
# 9            52             67                 28                  21
#
#   roadName  roadClosure           timeStamp
# 0   N103.1        False 2021-04-26 18:11:34
# 1   N103.0        False 2021-04-27 14:53:37
# 2   N103.1        False 2021-04-27 14:53:49
# 3   N103.2        False 2021-04-27 14:54:00
# 4   N101.0        False 2021-04-27 14:54:12
# 5   N103.0        False 2021-04-27 14:57:10
# 6   N103.1        False 2021-04-27 14:57:22
# 7   N103.2        False 2021-04-27 14:57:33
# 8   N101.0        False 2021-04-27 14:57:45
# 9   N101.1        False 2021-04-27 14:57:57

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178255 entries, 0 to 178254
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   currentSpeed        178255 non-null  int64
#  1   freeFlowSpeed       178255 non-null  int64
#  2   currentTravelTime   178255 non-null  int64
#  3   freeFlowTravelTime  178255 non-null  int64
#  4   roadName            178255 non-null  object
#  5   roadClosure         178255 non-null  bool
#  6   timeStamp           178255 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 8.3+ MB

# %%
print(traffic['roadName'].unique())
# Out:
# ['N103.1' 'N103.0' 'N103.2' 'N101.0' 'N101.1' 'N101.2' 'N101.3' 'N101.4'
#  'N101.5' 'Cent.0' 'Cent.1' 'Cent.2' 'Cent.3' 'Cent.4']

# %% [markdown]
# ### Filter Roads

# %%
traffic = traffic[(traffic['roadName'] == 'N103.2')]

# %% [markdown]
# ### Drop unwanted columns

# %%
traffic = traffic.drop(columns = ['roadClosure', 'freeFlowTravelTime', 'freeFlowSpeed', 'currentSpeed', 'roadName'])

# %% [markdown]
# ### Remove incomplete days

# %%
tfc = traffic[(traffic['timeStamp'].dt.day != 26) 
                        & (traffic['timeStamp'].dt.day != 27) 
                        & (traffic['timeStamp'].dt.day != 3)]
tfc.iloc[50:90]
# Out:
#       currentTravelTime           timeStamp
# 7092                 37 2021-04-28 00:58:59
# 7106                 37 2021-04-28 01:00:10
# 7120                 37 2021-04-28 01:01:20
# 7134                 37 2021-04-28 01:02:30
# 7148                 37 2021-04-28 01:03:40
# 7162                 37 2021-04-28 01:04:50
# 7176                 37 2021-04-28 01:06:00
# 7190                 37 2021-04-28 01:07:10
# 7204                 37 2021-04-28 01:08:20
# 7218                 37 2021-04-28 01:09:30
# 7232                 37 2021-04-28 01:10:40
# 7246                 37 2021-04-28 01:11:50
# 7260                 37 2021-04-28 01:13:00
# 7274                 37 2021-04-28 01:14:10
# 7288                 37 2021-04-28 01:15:20
# 7302                 37 2021-04-28 01:16:31
# 7316                 37 2021-04-28 01:17:41
# 7330                 37 2021-04-28 01:18:51
# 7344                 37 2021-04-28 01:20:01
# 7358                 37 2021-04-28 01:21:11
# 7372                 37 2021-04-28 01:22:21
# 7386                 37 2021-04-28 01:23:31
# 7400                 37 2021-04-28 01:24:41
# 7414                 37 2021-04-28 01:25:51
# 7428                 37 2021-04-28 01:27:01
# 7442                 37 2021-04-28 01:28:11
# 7456                 37 2021-04-28 01:29:21
# 7470                 37 2021-04-28 01:30:31
# 7484                 37 2021-04-28 01:31:41
# 7498                 37 2021-04-28 01:32:51
# 7512                 37 2021-04-28 01:34:02
# 7526                 37 2021-04-28 01:35:12
# 7540                 37 2021-04-28 01:36:22
# 7554                 37 2021-04-28 01:37:32
# 7568                 37 2021-04-28 01:38:42
# 7582                 37 2021-04-28 01:39:52
# 7596                 37 2021-04-28 01:41:02
# 7610                 37 2021-04-28 01:42:12
# 7624                 37 2021-04-28 01:43:22
# 7638                 37 2021-04-28 01:44:32

# %% [markdown]
# ### Treat Date and Time

# %%
tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")
# Out:
# <ipython-input-8-7e39a034e481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")

# %%
tfc
# Out:
#         currentTravelTime   timeStamp
# 6392                   37  2021042800
# 6406                   37  2021042800
# 6420                   37  2021042800
# 6434                   37  2021042800
# 6448                   37  2021042800
# ...                   ...         ...
# 178189                 50  2021050816
# 178203                 50  2021050816
# 178217                 50  2021050816
# 178231                 50  2021050816
# 178245                 50  2021050816
#
# [11044 rows x 2 columns]

# %%
traffic_by_date = tfc.groupby(['timeStamp'])
traffic_by_date_mean = traffic_by_date.mean()
traffic_by_date_mean
# Out:
#             currentTravelTime
# timeStamp
# 2021042800          37.000000
# 2021042801          37.000000
# 2021042802          37.000000
# 2021042803          37.000000
# 2021042804          37.000000
# ...                       ...
# 2021050812          40.365385
# 2021050813          44.058824
# 2021050814          42.921569
# 2021050815          41.884615
# 2021050816          44.222222
#
# [216 rows x 1 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

normalized_traffic = traffic_by_date_mean

normalized_traffic[['currentTravelTime']] = scaler.fit_transform(traffic_by_date_mean[['currentTravelTime']])

# %% [markdown]
# # LSTM

# %%
# 24 hours that make the sequence
TIMESTEPS = 24

# number of features used by the model (using conf. cases to predict conf. cases)
FEATURES = len(normalized_traffic.columns)

# number of days to forecast - we will forecast the next 12 hours
MULTISTEPS = 12

# time series cross validator
CV_SPLITS = 5

EPOCHS = 30

# 24 hours (1 day)
BATCH_SIZE = 24

# %%
# split data into training and validation sets
def split_data(training, percentage = 15):
    train_idx = np.arange(0, int(len(training) * (100 - percentage) / 100))
    val_idx = np.arange(int(len(training) * (100 - percentage) / 100 + 1), len(training))
    
    return train_idx, val_idx

# %%
# Preparing the dataset for the LSTM
def to_supervised(df, timesteps, features = 2):

    data = df.values
    x, y = [], []
    
    # iterate over the training set to create x and y
    dataset_size = len(data)
    
    for curr_pos in range(dataset_size):
        # end of the input sequence is the current position + the number 
        # of timesteps of the input sequence
        input_index = curr_pos + timesteps
        
        # end of the labels correspond to the end of the input sequence + 1
        label_index = input_index + 1
        
        # if we have enough data for this sequence 
        if label_index < dataset_size:
            x.append(data[curr_pos:input_index, :])
            y.append(data[input_index:label_index, 0])
        
    # using np.float32 for GPU performance
    return np.array(x).astype('float32'), np.array(y).astype('float32')


def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))
    

def build_model(timesteps, features, name, h_neurons = 128):
    
    model = tf.keras.models.Sequential(name = name)
    
    model.add(LSTM(h_neurons, return_sequences = True,
                   input_shape = (timesteps, features), 
                   activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(LSTM(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(features, activation = 'tanh'))
    
    return model


# Compiling and fit the model
def compile_and_fit(model, x, y, epochs = 25, batch_size = 24, cv_splits = 3):
    callback = []
    
    callback.append(EarlyStopping(monitor = 'val_loss', min_delta = 0, 
                                  patience = 5, verbose = 0, 
                                  mode = 'auto', restore_best_weights = True))
    
    callback.append(ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, 
                                      patience = 4, verbose = 0,
                                      mode = 'auto', cooldown = 0, 
                                      min_lr = 0.0001))
    
    # compile
    model.compile(loss = rmse, 
                  optimizer = 'adam', 
                  metrics = ['mae', rmse])    
    
    # fit
    hist_list = []
    loss_list = []
    
    # time series cross validator
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    
    for train_index, test_index in tscv.split(x):
        # further split into training and validation sets
        train_idx, val_idx = split_data(train_index, percentage = 15)
        
        x_train, y_train = x[train_idx], y[train_idx]
        x_val, y_val = x[val_idx], y[val_idx]
        #x_test, y_test = x[test_index], y[test_index]
        
        history = model.fit(x_train, y_train, validation_data = (x_val, y_val), 
                            epochs = epochs, batch_size = batch_size, 
                            shuffle = False, callbacks = callback)
        
        plot_learning_curves(history, model_name = model.get_config()['name'])
    
    return model, hist_list, loss_list


# Recursive Multi-step Forecast
def forecast(model, df, scaler, timesteps = 24, 
             multisteps = 6, features = 2, batch_size = 24):
    # getting the last sequence of known value
    input_seq = df[-timesteps:].values
    inp = input_seq
    forecasts = []
    
    # multisteps tells us how many iterations we want to perform, i.e., how many days
    # we want to predict
    for step in range(1, multisteps + 1):
     
        inp = inp.reshape(1, timesteps, features)
        
        yhat = model.predict(inp)
        
        print('yhat', yhat[0][features-1])
        
        yhat_inversed = scaler.inverse_transform(yhat)
        
        print('Transformed yhat', yhat_inversed[0][features-1])
        
        forecasts.append(round(yhat_inversed[0][features-1]))
    
        inp = np.append(inp[0], yhat[0])
        
        inp = inp[-timesteps*features:]
        
    return forecasts


def plot_prediction(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Travel Time For The Next 12H')
    plt.ylabel('Current Travel Time (min)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()


def plot_learning_curves(history, model_name):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['rmse'], color = 'mediumpurple',linewidth=3)
    plt.plot(history.history['val_rmse'], color = 'purple',linewidth=3)
    plt.title('Model ({}) rmse'.format(model_name))
    plt.ylabel('RMSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color = 'mediumpurple', linewidth=3)
    plt.plot(history.history['val_loss'], color = 'purple', linewidth=3)
    plt.title('Model ({}) loss'.format(model_name))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

# %%
# our supervised problem
x, y = to_supervised(normalized_traffic, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (191, 24, 1)
# Training labels shape: (191, 1)

# %%
# fitting the model
model = build_model(TIMESTEPS, FEATURES, name = 'test')
model, hist_list, loss_list = compile_and_fit(model, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 6s 2s/step - loss: 0.7458 - mae: 0.6734 - rmse: 0.7488 - val_loss: 0.6393 - val_mae: 0.6385 - val_rmse: 0.6393
# Epoch 2/30
# 2/2 [==============================] - 0s 210ms/step - loss: 0.6474 - mae: 0.5758 - rmse: 0.6723 - val_loss: 0.4529 - val_mae: 0.4513 - val_rmse: 0.4529
# Epoch 3/30
# 2/2 [==============================] - 0s 242ms/step - loss: 0.6381 - mae: 0.5580 - rmse: 0.6637 - val_loss: 0.4244 - val_mae: 0.4229 - val_rmse: 0.4244
# Epoch 4/30
# 2/2 [==============================] - 0s 262ms/step - loss: 0.6108 - mae: 0.5362 - rmse: 0.6381 - val_loss: 0.4441 - val_mae: 0.4431 - val_rmse: 0.4441
# Epoch 5/30
# 2/2 [==============================] - 0s 234ms/step - loss: 0.5951 - mae: 0.5246 - rmse: 0.6231 - val_loss: 0.4776 - val_mae: 0.4771 - val_rmse: 0.4776
# Epoch 6/30
# 2/2 [==============================] - 0s 199ms/step - loss: 0.5911 - mae: 0.5121 - rmse: 0.6163 - val_loss: 0.4975 - val_mae: 0.4973 - val_rmse: 0.4975
# Epoch 7/30
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5859 - mae: 0.5113 - rmse: 0.6088 - val_loss: 0.4897 - val_mae: 0.4896 - val_rmse: 0.4897
# Epoch 8/30
# Epoch 15/30
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3787 - mae: 0.2718 - rmse: 0.3796 - val_loss: 0.4339 - val_mae: 0.3506 - val_rmse: 0.4339
# Epoch 16/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3841 - mae: 0.2825 - rmse: 0.3862 - val_loss: 0.4365 - val_mae: 0.3499 - val_rmse: 0.4365
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])

# %%
# Recursive Multi-step Forecast
forecasts = forecast(model,normalized_traffic, scaler, 
                              TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction(normalized_traffic, forecasts, scaler)
# Out:
# yhat -0.57094324
# Transformed yhat 42.926872
# yhat -0.6179292
# Transformed yhat 42.27782
# yhat -0.65458417
# Transformed yhat 41.77148
# yhat -0.6785647
# Transformed yhat 41.44022
# yhat -0.70043415
# Transformed yhat 41.13812
# yhat -0.7208276
# Transformed yhat 40.85641
# yhat -0.73628926
# Transformed yhat 40.64283
# yhat -0.74628896
# Transformed yhat 40.504696
# yhat -0.75218195
# Transformed yhat 40.42329
# yhat -0.75414896
# Transformed yhat 40.39612
# yhat -0.7524953
# Transformed yhat 40.41896
# yhat -0.7526719
# Transformed yhat 40.416523
# Real data: [61.33333333 51.32692308 39.58823529 38.92307692 40.58823529 39.50980392
#  38.         38.         38.         38.         43.98039216 37.
#  37.         37.         37.96153846 40.78431373 42.03921569 48.30769231
#  45.54901961 40.36538462 44.05882353 42.92156863 41.88461538 44.22222222]
# Forecasting values: [43, 42, 42, 41, 41, 41, 41, 41, 40, 40, 40, 40]

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=1)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        print('-',h)
        if h == 1:
            
        else:
            newHour = ts + pd.DateOffset(hour=h+1)
            tss = tss+1
            ts = newHour
            hour.append(newHour)
            print(newHour)
        
print(hour)
# Out:
# - 16
# 2021-05-08 15:10:16
# - 15
# 2021-05-08 14:10:16
# - 14
# 2021-05-08 13:10:16
# - 13
# 2021-05-08 12:10:16
# - 12
# 2021-05-08 11:10:16
# - 11
# 2021-05-08 10:10:16
# - 10
# 2021-05-08 09:10:16
# - 1
# - 1
# - 1
# - 1
# [Timestamp('2021-05-08 15:10:16'), Timestamp('2021-05-08 14:10:16'), Timestamp('2021-05-08 13:10:16'), Timestamp('2021-05-08 12:10:16'), Timestamp('2021-05-08 11:10:16'), Timestamp('2021-05-08 10:10:16'), Timestamp('2021-05-08 09:10:16'), Timestamp('2021-05-09 01:10:16')]

# %%
import csv
'''
with open('predictions.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'N103.2',forecasts[i],hour[i]
        writer.writerow(d)
        '''

# %% [markdown]
# # LSTM Travel Time Prediction - N103.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
traffic = pd.read_csv('../db.csv', parse_dates = ["timeStamp"])
traffic.head(10)
# Out:
#    currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# 0            64             64                 21                  21
# 1            34             43                 49                  39
# 2            64             64                 21                  21
# 3            51             51                 37                  37
# 4            74             74                 21                  21
# 5            33             43                 51                  39
# 6            64             64                 21                  21
# 7            39             50                 49                  38
# 8            74             74                 21                  21
# 9            52             67                 28                  21
#
#   roadName  roadClosure           timeStamp
# 0   N103.1        False 2021-04-26 18:11:34
# 1   N103.0        False 2021-04-27 14:53:37
# 2   N103.1        False 2021-04-27 14:53:49
# 3   N103.2        False 2021-04-27 14:54:00
# 4   N101.0        False 2021-04-27 14:54:12
# 5   N103.0        False 2021-04-27 14:57:10
# 6   N103.1        False 2021-04-27 14:57:22
# 7   N103.2        False 2021-04-27 14:57:33
# 8   N101.0        False 2021-04-27 14:57:45
# 9   N101.1        False 2021-04-27 14:57:57

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178255 entries, 0 to 178254
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   currentSpeed        178255 non-null  int64
#  1   freeFlowSpeed       178255 non-null  int64
#  2   currentTravelTime   178255 non-null  int64
#  3   freeFlowTravelTime  178255 non-null  int64
#  4   roadName            178255 non-null  object
#  5   roadClosure         178255 non-null  bool
#  6   timeStamp           178255 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 8.3+ MB

# %%
print(traffic['roadName'].unique())
# Out:
# ['N103.1' 'N103.0' 'N103.2' 'N101.0' 'N101.1' 'N101.2' 'N101.3' 'N101.4'
#  'N101.5' 'Cent.0' 'Cent.1' 'Cent.2' 'Cent.3' 'Cent.4']

# %% [markdown]
# ### Filter Roads

# %%
traffic = traffic[(traffic['roadName'] == 'N103.0')]

# %% [markdown]
# ### Drop unwanted columns

# %%
traffic = traffic.drop(columns = ['roadClosure', 'freeFlowTravelTime', 'freeFlowSpeed', 'roadName'])

# %% [markdown]
# ### Remove incomplete days

# %%
tfc = traffic[(traffic['timeStamp'].dt.day != 26) 
                        & (traffic['timeStamp'].dt.day != 27) 
                        & (traffic['timeStamp'].dt.day != 3)]

# %% [markdown]
# ### Treat Date and Time

# %%
tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")
# Out:
# <ipython-input-8-7e39a034e481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")

# %%
tfc
# Out:
#         currentSpeed  currentTravelTime   timeStamp
# 6390              44                 38  2021042800
# 6404              44                 38  2021042800
# 6418              44                 38  2021042800
# 6432              44                 38  2021042800
# 6446              44                 38  2021042800
# ...              ...                ...         ...
# 178187            43                 39  2021050816
# 178201            43                 39  2021050816
# 178215            43                 39  2021050816
# 178229            43                 39  2021050816
# 178243            43                 39  2021050816
#
# [11044 rows x 3 columns]

# %%
traffic_by_date = tfc.groupby(['timeStamp'])
traffic_by_date_mean = traffic_by_date.mean()
traffic_by_date_mean
# Out:
#             currentSpeed  currentTravelTime
# timeStamp
# 2021042800     44.000000          38.000000
# 2021042801     44.000000          38.000000
# 2021042802     44.000000          38.000000
# 2021042803     44.000000          38.000000
# 2021042804     44.000000          38.000000
# ...                  ...                ...
# 2021050812     42.500000          39.692308
# 2021050813     42.607843          39.607843
# 2021050814     43.000000          39.000000
# 2021050815     39.403846          43.461538
# 2021050816     43.000000          39.000000
#
# [216 rows x 2 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

normalized_Time = traffic_by_date_mean
normalized_Speed = traffic_by_date_mean

normalized_Time[['currentTravelTime']] = scaler.fit_transform(traffic_by_date_mean[['currentTravelTime']])
normalized_Time = normalized_Time.drop(columns = ['currentSpeed'])
normalized_Time

normalized_Speed[['currentSpeed']] = scaler.fit_transform(traffic_by_date_mean[['currentSpeed']])
normalized_Speed = normalized_Speed.drop(columns = ['currentTravelTime'])
normalized_Speed
# Out:
#             currentSpeed
# timeStamp
# 2021042800      1.000000
# 2021042801      1.000000
# 2021042802      1.000000
# 2021042803      1.000000
# 2021042804      1.000000
# ...                  ...
# 2021050812      0.865285
# 2021050813      0.874970
# 2021050814      0.910190
# 2021050815      0.587219
# 2021050816      0.910190
#
# [216 rows x 1 columns]

# %% [markdown]
# # LSTM - Time

# %%
# 24 hours that make the sequence
TIMESTEPS = 24

# number of features used by the model (using conf. cases to predict conf. cases)
FEATURES = len(normalized_Time.columns)

# number of hours to forecast - we will forecast the next 12 hours
MULTISTEPS = 12

# time series cross validator
CV_SPLITS = 5

EPOCHS = 30

# 24 hours (1 day)
BATCH_SIZE = 24

# %%
# split data into training and validation sets
def split_data(training, percentage = 15):
    train_idx = np.arange(0, int(len(training) * (100 - percentage) / 100))
    val_idx = np.arange(int(len(training) * (100 - percentage) / 100 + 1), len(training))
    
    return train_idx, val_idx

# %%
# Preparing the dataset for the LSTM
def to_supervised(df, timesteps, features = 2):

    data = df.values
    x, y = [], []
    
    # iterate over the training set to create x and y
    dataset_size = len(data)
    
    for curr_pos in range(dataset_size):
        # end of the input sequence is the current position + the number 
        # of timesteps of the input sequence
        input_index = curr_pos + timesteps
        
        # end of the labels correspond to the end of the input sequence + 1
        label_index = input_index + 1
        
        # if we have enough data for this sequence 
        if label_index < dataset_size:
            x.append(data[curr_pos:input_index, :])
            y.append(data[input_index:label_index, 0])
        
    # using np.float32 for GPU performance
    return np.array(x).astype('float32'), np.array(y).astype('float32')


def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))
    

def build_model(timesteps, features, name, h_neurons = 128):
    
    model = tf.keras.models.Sequential(name = name)
    
    model.add(LSTM(h_neurons, return_sequences = True,
                   input_shape = (timesteps, features), 
                   activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(LSTM(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(features, activation = 'tanh'))
    
    return model


# Compiling and fit the model
def compile_and_fit(model, x, y, epochs = 25, batch_size = 24, cv_splits = 3):
    callback = []
    
    callback.append(EarlyStopping(monitor = 'val_loss', min_delta = 0, 
                                  patience = 5, verbose = 0, 
                                  mode = 'auto', restore_best_weights = True))
    
    callback.append(ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, 
                                      patience = 4, verbose = 0,
                                      mode = 'auto', cooldown = 0, 
                                      min_lr = 0.0001))
    
    # compile
    model.compile(loss = rmse, 
                  optimizer = 'adam', 
                  metrics = ['mae', rmse])    
    
    # fit
    hist_list = []
    loss_list = []
    
    # time series cross validator
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    
    for train_index, test_index in tscv.split(x):
        # further split into training and validation sets
        train_idx, val_idx = split_data(train_index, percentage = 15)
        
        x_train, y_train = x[train_idx], y[train_idx]
        x_val, y_val = x[val_idx], y[val_idx]
        #x_test, y_test = x[test_index], y[test_index]
        
        history = model.fit(x_train, y_train, validation_data = (x_val, y_val), 
                            epochs = epochs, batch_size = batch_size, 
                            shuffle = False, callbacks = callback)
        
        plot_learning_curves(history, model_name = model.get_config()['name'])
    
    return model, hist_list, loss_list


# Recursive Multi-step Forecast
def forecast(model, df, scaler, timesteps = 24, 
             multisteps = 6, features = 2, batch_size = 24):
    # getting the last sequence of known value
    input_seq = df[-timesteps:].values
    inp = input_seq
    forecasts = []
    
    # multisteps tells us how many iterations we want to perform, i.e., how many days
    # we want to predict
    for step in range(1, multisteps + 1):
     
        inp = inp.reshape(1, timesteps, features)
        
        yhat = model.predict(inp)
        
        print('yhat', yhat[0][features-1])
        
        yhat_inversed = scaler.inverse_transform(yhat)
        
        print('Transformed yhat', yhat_inversed[0][features-1])
        
        forecasts.append(round(yhat_inversed[0][features-1]))
    
        inp = np.append(inp[0], yhat[0])
        
        inp = inp[-timesteps*features:]
        
    return forecasts


def plot_prediction(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Travel Time For The Next 12H')
    plt.ylabel('Current Travel Time (min)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()

def plot_prediction_Speed(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Speed For The Next 12H')
    plt.ylabel('Current Speed (KM/H)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()



def plot_learning_curves(history, model_name):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['rmse'], color = 'mediumpurple',linewidth=3)
    plt.plot(history.history['val_rmse'], color = 'purple',linewidth=3)
    plt.title('Model ({}) rmse'.format(model_name))
    plt.ylabel('RMSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color = 'mediumpurple', linewidth=3)
    plt.plot(history.history['val_loss'], color = 'purple', linewidth=3)
    plt.title('Model ({}) loss'.format(model_name))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

# %%
# our supervised problem
x, y = to_supervised(normalized_Time, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (191, 24, 1)
# Training labels shape: (191, 1)

# %%
# fitting the model
modelTime = build_model(TIMESTEPS, FEATURES, name = 'test')
modelTime, hist_list, loss_list = compile_and_fit(modelTime, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.7902 - mae: 0.7241 - rmse: 0.7325 - val_loss: 0.3484 - val_mae: 0.3481 - val_rmse: 0.3484
# Epoch 2/30
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3525 - mae: 0.3216 - rmse: 0.3461 - val_loss: 0.0481 - val_mae: 0.0479 - val_rmse: 0.0481
# Epoch 3/30
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3516 - mae: 0.2284 - rmse: 0.3540 - val_loss: 0.0120 - val_mae: 0.0119 - val_rmse: 0.0120
# Epoch 4/30
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3655 - mae: 0.2245 - rmse: 0.3663 - val_loss: 0.0080 - val_mae: 0.0079 - val_rmse: 0.0080
# Epoch 5/30
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3686 - mae: 0.2194 - rmse: 0.3693 - val_loss: 0.0103 - val_mae: 0.0102 - val_rmse: 0.0103
# Epoch 6/30
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3678 - mae: 0.2182 - rmse: 0.3685 - val_loss: 0.0205 - val_mae: 0.0202 - val_rmse: 0.0205
# Epoch 7/30
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3556 - mae: 0.2160 - rmse: 0.3530 - val_loss: 0.0681 - val_mae: 0.0672 - val_rmse: 0.0681
# Epoch 8/30
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3461 - mae: 0.2414 - rmse: 0.3416 - val_loss: 0.2014 - val_mae: 0.1996 - val_rmse: 0.2014
# Epoch 9/30
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3171 - mae: 0.2629 - rmse: 0.3230 - val_loss: 0.2023 - val_mae: 0.2005 - val_rmse: 0.2023
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2422 - mae: 0.1279 - rmse: 0.1932 - val_loss: 0.0243 - val_mae: 0.0243 - val_rmse: 0.0243
# 6/6 [==============================] - 0s 64ms/step - loss: 0.3021 - mae: 0.1952 - rmse: 0.3116 - val_loss: 0.3507 - val_mae: 0.2494 - val_rmse: 0.3507
# Epoch 15/30
# 6/6 [==============================] - 0s 73ms/step - loss: 0.2947 - mae: 0.1933 - rmse: 0.3039 - val_loss: 0.3518 - val_mae: 0.2488 - val_rmse: 0.3518
# Epoch 16/30
# 6/6 [==============================] - 0s 76ms/step - loss: 0.2947 - mae: 0.1898 - rmse: 0.3036 - val_loss: 0.3517 - val_mae: 0.2487 - val_rmse: 0.3517
# Epoch 17/30
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3020 - mae: 0.1982 - rmse: 0.3108 - val_loss: 0.3522 - val_mae: 0.2484 - val_rmse: 0.3522
# Epoch 18/30
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2970 - mae: 0.1932 - rmse: 0.3061 - val_loss: 0.3529 - val_mae: 0.2480 - val_rmse: 0.3529
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])

# %%
# Recursive Multi-step Forecast
forecasts = forecast(modelTime,normalized_Time, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction(normalized_Time, forecasts, scaler)
# Out:
# yhat -0.9144737
# Transformed yhat 22.683071
# yhat -0.9139227
# Transformed yhat 22.689207
# yhat -0.9134114
# Transformed yhat 22.6949
# yhat -0.9130744
# Transformed yhat 22.698652
# yhat -0.9127707
# Transformed yhat 22.702034
# yhat -0.9125217
# Transformed yhat 22.704805
# yhat -0.9123078
# Transformed yhat 22.707188
# yhat -0.9121262
# Transformed yhat 22.70921
# yhat -0.91197485
# Transformed yhat 22.710896
# yhat -0.91185117
# Transformed yhat 22.712273
# yhat -0.91175216
# Transformed yhat 22.713375
# yhat -0.91167486
# Transformed yhat 22.714235
# Real data: [28.34440972 26.66476044 22.62948174 22.37287025 21.79028662 21.73076923
#  21.73076923 21.73076923 21.73076923 21.73076923 21.73076923 21.73076923
#  21.73076923 21.73076923 22.28531102 22.03430789 22.03430789 24.87328716
#  23.72460163 22.24445005 22.21881179 22.03430789 23.38855731 22.03430789]
# Forecasting values: [23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23]

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv
'''
with open('predictionsTime.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'N103.0',forecasts[i],hour[i]
        writer.writerow(d)
        '''

# %% [markdown]
# # LSTM - Speed

# %%
# our supervised problem
x, y = to_supervised(normalized_Speed, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (191, 24, 1)
# Training labels shape: (191, 1)

# %%
# fitting the model
modelSpeed = build_model(TIMESTEPS, FEATURES, name = 'test')
modelSpeed , hist_list, loss_list = compile_and_fit(modelSpeed, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 7s 2s/step - loss: 0.7628 - mae: 0.7131 - rmse: 0.7569 - val_loss: 0.5091 - val_mae: 0.5072 - val_rmse: 0.5091
# Epoch 2/30
# 2/2 [==============================] - 0s 165ms/step - loss: 0.6556 - mae: 0.5804 - rmse: 0.6624 - val_loss: 0.3069 - val_mae: 0.3040 - val_rmse: 0.3069
# Epoch 3/30
# 2/2 [==============================] - 0s 140ms/step - loss: 0.6540 - mae: 0.5612 - rmse: 0.6697 - val_loss: 0.2790 - val_mae: 0.2762 - val_rmse: 0.2790
# Epoch 4/30
# 2/2 [==============================] - 0s 155ms/step - loss: 0.6512 - mae: 0.5424 - rmse: 0.6683 - val_loss: 0.3302 - val_mae: 0.3278 - val_rmse: 0.3302
# Epoch 5/30
# 2/2 [==============================] - 0s 144ms/step - loss: 0.6237 - mae: 0.5336 - rmse: 0.6362 - val_loss: 0.3959 - val_mae: 0.3942 - val_rmse: 0.3959
# Epoch 6/30
# 2/2 [==============================] - 0s 152ms/step - loss: 0.5902 - mae: 0.5127 - rmse: 0.6060 - val_loss: 0.4398 - val_mae: 0.4387 - val_rmse: 0.4398
# Epoch 7/30
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5967 - mae: 0.5394 - rmse: 0.6172 - val_loss: 0.4344 - val_mae: 0.4338 - val_rmse: 0.4344
# Epoch 8/30
# 2/2 [==============================] - 0s 131ms/step - loss: 0.5799 - mae: 0.5318 - rmse: 0.5964 - val_loss: 0.4317 - val_mae: 0.4311 - val_rmse: 0.4317
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 3/3 [==============================] - 0s 138ms/step - loss: 0.4575 - mae: 0.3686 - rmse: 0.3748 - val_loss: 0.0466 - val_mae: 0.0466 - val_rmse: 0.0466
# Epoch 2/30
# 3/3 [==============================] - 0s 103ms/step - loss: 0.4510 - mae: 0.3627 - rmse: 0.3670 - val_loss: 0.0337 - val_mae: 0.0337 - val_rmse: 0.0337
# Epoch 3/30
# 3/3 [==============================] - 0s 74ms/step - loss: 0.4549 - mae: 0.3575 - rmse: 0.3689 - val_loss: 0.0175 - val_mae: 0.0175 - val_rmse: 0.0175
# Epoch 4/30
# 3/3 [==============================] - 0s 75ms/step - loss: 0.4321 - mae: 0.3336 - rmse: 0.3428 - val_loss: 0.0025 - val_mae: 0.0024 - val_rmse: 0.0025
# Epoch 5/30
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4432 - mae: 0.3275 - rmse: 0.3547 - val_loss: 0.0087 - val_mae: 0.0087 - val_rmse: 0.0087
# Epoch 6/30
# 3/3 [==============================] - 0s 69ms/step - loss: 0.4459 - mae: 0.3221 - rmse: 0.3589 - val_loss: 0.0159 - val_mae: 0.0158 - val_rmse: 0.0159
# Epoch 7/30
# Epoch 25/30
# 6/6 [==============================] - 1s 120ms/step - loss: 0.4298 - mae: 0.2930 - rmse: 0.4369 - val_loss: 0.5639 - val_mae: 0.4021 - val_rmse: 0.5639
# Epoch 26/30
# 6/6 [==============================] - 1s 111ms/step - loss: 0.4286 - mae: 0.2898 - rmse: 0.4347 - val_loss: 0.5617 - val_mae: 0.3984 - val_rmse: 0.5617
# Epoch 27/30
# 6/6 [==============================] - 1s 90ms/step - loss: 0.4325 - mae: 0.2928 - rmse: 0.4395 - val_loss: 0.5588 - val_mae: 0.3942 - val_rmse: 0.5588
# Epoch 28/30
# 6/6 [==============================] - 1s 104ms/step - loss: 0.4322 - mae: 0.2976 - rmse: 0.4386 - val_loss: 0.5586 - val_mae: 0.3920 - val_rmse: 0.5586
# Epoch 29/30
# 6/6 [==============================] - 1s 160ms/step - loss: 0.4319 - mae: 0.2919 - rmse: 0.4383 - val_loss: 0.5596 - val_mae: 0.3910 - val_rmse: 0.5596
# Epoch 30/30
# 6/6 [==============================] - 1s 121ms/step - loss: 0.4303 - mae: 0.2940 - rmse: 0.4370 - val_loss: 0.5593 - val_mae: 0.3890 - val_rmse: 0.5593
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])

# %%
# Recursive Multi-step Forecast
forecastSpeed = forecast(modelSpeed,normalized_Speed, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction_Speed(normalized_Speed, forecastSpeed, scaler)
# Out:
# yhat 0.785787
# Transformed yhat 41.61482
# yhat 0.807388
# Transformed yhat 41.85534
# yhat 0.8236433
# Transformed yhat 42.036335
# yhat 0.8340825
# Transformed yhat 42.152573
# yhat 0.8422908
# Transformed yhat 42.24397
# yhat 0.84810466
# Transformed yhat 42.308704
# yhat 0.8521158
# Transformed yhat 42.353367
# yhat 0.8545312
# Transformed yhat 42.38026
# yhat 0.85553664
# Transformed yhat 42.391457
# yhat 0.85533476
# Transformed yhat 42.38921
# yhat 0.85413784
# Transformed yhat 42.37588
# yhat 0.85216236
# Transformed yhat 42.353886
# Real data: [28.42307692 31.66666667 41.7254902  42.11538462 43.82352941 44.
#  44.         44.         44.         44.         44.         44.
#  44.         44.         43.19230769 43.         43.         36.01960784
#  38.31372549 42.5        42.60784314 43.         39.40384615 43.        ]
# Forecasting values: [42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv
'''
with open('predictionsSpeed.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'N103.0',forecasts[i],hour[i]
        writer.writerow(d)
'''

# %% [markdown]
# # LSTM Travel Time + Speed Prediction - Cent.4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
traffic = pd.read_csv('../db.csv', parse_dates = ["timeStamp"])
traffic.head(10)
# Out:
#    currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# 0            64             64                 21                  21
# 1            34             43                 49                  39
# 2            64             64                 21                  21
# 3            51             51                 37                  37
# 4            74             74                 21                  21
# 5            33             43                 51                  39
# 6            64             64                 21                  21
# 7            39             50                 49                  38
# 8            74             74                 21                  21
# 9            52             67                 28                  21
#
#   roadName  roadClosure           timeStamp
# 0   N103.1        False 2021-04-26 18:11:34
# 1   N103.0        False 2021-04-27 14:53:37
# 2   N103.1        False 2021-04-27 14:53:49
# 3   N103.2        False 2021-04-27 14:54:00
# 4   N101.0        False 2021-04-27 14:54:12
# 5   N103.0        False 2021-04-27 14:57:10
# 6   N103.1        False 2021-04-27 14:57:22
# 7   N103.2        False 2021-04-27 14:57:33
# 8   N101.0        False 2021-04-27 14:57:45
# 9   N101.1        False 2021-04-27 14:57:57

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245563 entries, 0 to 245562
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   currentSpeed        245563 non-null  int64
#  1   freeFlowSpeed       245563 non-null  int64
#  2   currentTravelTime   245563 non-null  int64
#  3   freeFlowTravelTime  245563 non-null  int64
#  4   roadName            245563 non-null  object
#  5   roadClosure         245563 non-null  bool
#  6   timeStamp           245563 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 11.5+ MB

# %%
print(traffic['roadName'].unique())
# Out:
# ['N103.1' 'N103.0' 'N103.2' 'N101.0' 'N101.1' 'N101.2' 'N101.3' 'N101.4'
#  'N101.5' 'Cent.0' 'Cent.1' 'Cent.2' 'Cent.3' 'Cent.4']

# %% [markdown]
# ### Filter Roads

# %%
traffic = traffic[(traffic['roadName'] == 'Cent.4')]

# %% [markdown]
# ### Drop unwanted columns

# %%
traffic = traffic.drop(columns = ['roadClosure', 'freeFlowTravelTime', 'freeFlowSpeed', 'roadName'])

# %% [markdown]
# ### Remove incomplete days

# %%
tfc = traffic[(traffic['timeStamp'].dt.day != 26) 
                        & (traffic['timeStamp'].dt.day != 27) 
                        & (traffic['timeStamp'].dt.day != 3)]

# %% [markdown]
# ### Treat Date and Time

# %%
tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")
# Out:
# <ipython-input-8-7e39a034e481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")

# %%
tfc
# Out:
#         currentSpeed  currentTravelTime   timeStamp
# 6389              77                 33  2021042800
# 6403              77                 33  2021042800
# 6417              77                 33  2021042800
# 6431              77                 33  2021042800
# 6445              77                 33  2021042800
# ...              ...                ...         ...
# 245498            77                 33  2021051213
# 245512            77                 33  2021051213
# 245526            77                 33  2021051213
# 245540            77                 33  2021051213
# 245554            77                 33  2021051213
#
# [15851 rows x 3 columns]

# %%
traffic_by_date = tfc.groupby(['timeStamp'])
traffic_by_date_mean = traffic_by_date.mean()
traffic_by_date_mean
# Out:
#             currentSpeed  currentTravelTime
# timeStamp
# 2021042800     77.000000          33.000000
# 2021042801     77.000000          33.000000
# 2021042802     67.137255          38.666667
# 2021042803     76.346154          33.346154
# 2021042804     77.000000          33.000000
# ...                  ...                ...
# 2021051209     76.673077          33.173077
# 2021051210     77.000000          33.000000
# 2021051211     75.843137          33.588235
# 2021051212     75.500000          33.980769
# 2021051213     77.000000          33.000000
#
# [309 rows x 2 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

normalized_Time = traffic_by_date_mean
normalized_Speed = traffic_by_date_mean

normalized_Time[['currentTravelTime']] = scaler.fit_transform(traffic_by_date_mean[['currentTravelTime']])
normalized_Time = normalized_Time.drop(columns = ['currentSpeed'])
normalized_Time

normalized_Speed[['currentSpeed']] = scaler.fit_transform(traffic_by_date_mean[['currentSpeed']])
normalized_Speed = normalized_Speed.drop(columns = ['currentTravelTime'])
normalized_Speed
# Out:
#             currentSpeed
# timeStamp
# 2021042800      1.000000
# 2021042801      1.000000
# 2021042802      0.603469
# 2021042803      0.973712
# 2021042804      1.000000
# ...                  ...
# 2021051209      0.986856
# 2021051210      1.000000
# 2021051211      0.953488
# 2021051212      0.939693
# 2021051213      1.000000
#
# [309 rows x 1 columns]

# %% [markdown]
# # LSTM - Time

# %%
# 24 hours that make the sequence
TIMESTEPS = 24

# number of features used by the model (using conf. cases to predict conf. cases)
FEATURES = len(normalized_Time.columns)

# number of hours to forecast - we will forecast the next 12 hours
MULTISTEPS = 12

# time series cross validator
CV_SPLITS = 5

EPOCHS = 30

# 24 hours (1 day)
BATCH_SIZE = 24

# %%
# split data into training and validation sets
def split_data(training, percentage = 15):
    train_idx = np.arange(0, int(len(training) * (100 - percentage) / 100))
    val_idx = np.arange(int(len(training) * (100 - percentage) / 100 + 1), len(training))
    
    return train_idx, val_idx

# %%
# Preparing the dataset for the LSTM
def to_supervised(df, timesteps, features = 2):

    data = df.values
    x, y = [], []
    
    # iterate over the training set to create x and y
    dataset_size = len(data)
    
    for curr_pos in range(dataset_size):
        # end of the input sequence is the current position + the number 
        # of timesteps of the input sequence
        input_index = curr_pos + timesteps
        
        # end of the labels correspond to the end of the input sequence + 1
        label_index = input_index + 1
        
        # if we have enough data for this sequence 
        if label_index < dataset_size:
            x.append(data[curr_pos:input_index, :])
            y.append(data[input_index:label_index, 0])
        
    # using np.float32 for GPU performance
    return np.array(x).astype('float32'), np.array(y).astype('float32')


def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))
    

def build_model(timesteps, features, name, h_neurons = 128):
    
    model = tf.keras.models.Sequential(name = name)
    
    model.add(LSTM(h_neurons, return_sequences = True,
                   input_shape = (timesteps, features), 
                   activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(LSTM(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(features, activation = 'tanh'))
    
    return model


# Compiling and fit the model
def compile_and_fit(model, x, y, epochs = 25, batch_size = 24, cv_splits = 3):
    callback = []
    
    callback.append(EarlyStopping(monitor = 'val_loss', min_delta = 0, 
                                  patience = 5, verbose = 0, 
                                  mode = 'auto', restore_best_weights = True))
    
    callback.append(ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, 
                                      patience = 4, verbose = 0,
                                      mode = 'auto', cooldown = 0, 
                                      min_lr = 0.0001))
    
    # compile
    model.compile(loss = rmse, 
                  optimizer = 'adam', 
                  metrics = ['mae', rmse])    
    
    # fit
    hist_list = []
    loss_list = []
    
    # time series cross validator
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    
    for train_index, test_index in tscv.split(x):
        # further split into training and validation sets
        train_idx, val_idx = split_data(train_index, percentage = 15)
        
        x_train, y_train = x[train_idx], y[train_idx]
        x_val, y_val = x[val_idx], y[val_idx]
        #x_test, y_test = x[test_index], y[test_index]
        
        history = model.fit(x_train, y_train, validation_data = (x_val, y_val), 
                            epochs = epochs, batch_size = batch_size, 
                            shuffle = False, callbacks = callback)
        
        plot_learning_curves(history, model_name = model.get_config()['name'])
    
    return model, hist_list, loss_list


# Recursive Multi-step Forecast
def forecast(model, df, scaler, timesteps = 24, 
             multisteps = 6, features = 2, batch_size = 24):
    # getting the last sequence of known value
    input_seq = df[-timesteps:].values
    inp = input_seq
    forecasts = []
    
    # multisteps tells us how many iterations we want to perform, i.e., how many days
    # we want to predict
    for step in range(1, multisteps + 1):
     
        inp = inp.reshape(1, timesteps, features)
        
        yhat = model.predict(inp)
        
        print('yhat', yhat[0][features-1])
        
        yhat_inversed = scaler.inverse_transform(yhat)
        
        print('Transformed yhat', yhat_inversed[0][features-1])
        
        forecasts.append(round(yhat_inversed[0][features-1]))
    
        inp = np.append(inp[0], yhat[0])
        
        inp = inp[-timesteps*features:]
        
    return forecasts


def plot_prediction(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Travel Time For The Next 12H')
    plt.ylabel('Current Travel Time (min)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()

def plot_prediction_Speed(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Speed For The Next 12H')
    plt.ylabel('Current Speed (KM/H)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()



def plot_learning_curves(history, model_name):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['rmse'], color = 'mediumpurple',linewidth=3)
    plt.plot(history.history['val_rmse'], color = 'purple',linewidth=3)
    plt.title('Model ({}) rmse'.format(model_name))
    plt.ylabel('RMSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color = 'mediumpurple', linewidth=3)
    plt.plot(history.history['val_loss'], color = 'purple', linewidth=3)
    plt.title('Model ({}) loss'.format(model_name))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

# %%
# our supervised problem
x, y = to_supervised(normalized_Time, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (284, 24, 1)
# Training labels shape: (284, 1)

# %%
# fitting the model
modelTime = build_model(TIMESTEPS, FEATURES, name = 'test')
modelTime, hist_list, loss_list = compile_and_fit(modelTime, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.6807 - mae: 0.6523 - rmse: 0.6592 - val_loss: 0.1152 - val_mae: 0.1151 - val_rmse: 0.1152
# Epoch 2/30
# 2/2 [==============================] - 0s 131ms/step - loss: 0.2293 - mae: 0.1553 - rmse: 0.2244 - val_loss: 0.0045 - val_mae: 0.0044 - val_rmse: 0.0045
# Epoch 3/30
# 2/2 [==============================] - 0s 87ms/step - loss: 0.2386 - mae: 0.0918 - rmse: 0.2331 - val_loss: 0.0037 - val_mae: 0.0016 - val_rmse: 0.0037
# Epoch 4/30
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2397 - mae: 0.0907 - rmse: 0.2342 - val_loss: 0.0038 - val_mae: 0.0014 - val_rmse: 0.0038
# Epoch 5/30
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2402 - mae: 0.0909 - rmse: 0.2346 - val_loss: 0.0038 - val_mae: 0.0014 - val_rmse: 0.0038
# Epoch 6/30
# 2/2 [==============================] - 0s 122ms/step - loss: 0.2402 - mae: 0.0909 - rmse: 0.2346 - val_loss: 0.0038 - val_mae: 0.0014 - val_rmse: 0.0038
# Epoch 7/30
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2402 - mae: 0.0909 - rmse: 0.2346 - val_loss: 0.0038 - val_mae: 0.0014 - val_rmse: 0.0038
# Epoch 8/30
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2402 - mae: 0.0909 - rmse: 0.2346 - val_loss: 0.0038 - val_mae: 0.0014 - val_rmse: 0.0038
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 4/4 [==============================] - 1s 169ms/step - loss: 0.1407 - mae: 0.0506 - rmse: 0.1439 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# Epoch 2/30
# 4/4 [==============================] - 0s 80ms/step - loss: 0.1406 - mae: 0.0507 - rmse: 0.1438 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# Epoch 3/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1408 - mae: 0.0506 - rmse: 0.1440 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# Epoch 4/30
# 4/4 [==============================] - 0s 75ms/step - loss: 0.1408 - mae: 0.0506 - rmse: 0.1440 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# Epoch 5/30
# 4/4 [==============================] - 0s 80ms/step - loss: 0.1406 - mae: 0.0505 - rmse: 0.1438 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# Epoch 6/30
# 4/4 [==============================] - 0s 101ms/step - loss: 0.1408 - mae: 0.0507 - rmse: 0.1440 - val_loss: 0.1119 - val_mae: 0.0517 - val_rmse: 0.1119
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1411 - mae: 0.0558 - rmse: 0.1611 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 2/30
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1411 - mae: 0.0558 - rmse: 0.1610 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 3/30
# 6/6 [==============================] - 1s 82ms/step - loss: 0.1410 - mae: 0.0558 - rmse: 0.1609 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 4/30
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1411 - mae: 0.0558 - rmse: 0.1610 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 5/30
# 6/6 [==============================] - 1s 104ms/step - loss: 0.1411 - mae: 0.0558 - rmse: 0.1610 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 6/30
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1410 - mae: 0.0558 - rmse: 0.1610 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 7/30
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1410 - mae: 0.0559 - rmse: 0.1609 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 8/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1411 - mae: 0.0558 - rmse: 0.1608 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 9/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1409 - mae: 0.0558 - rmse: 0.1608 - val_loss: 0.0105 - val_mae: 0.0046 - val_rmse: 0.0105
# Epoch 10/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1409 - mae: 0.0558 - rmse: 0.1609 - val_loss: 0.0105 - val_mae: 0.0047 - val_rmse: 0.0105
# Epoch 11/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1410 - mae: 0.0558 - rmse: 0.1609 - val_loss: 0.0105 - val_mae: 0.0047 - val_rmse: 0.0105
# Epoch 12/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1410 - mae: 0.0560 - rmse: 0.1609 - val_loss: 0.0104 - val_mae: 0.0047 - val_rmse: 0.0104
# Epoch 13/30
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1409 - mae: 0.0557 - rmse: 0.1608 - val_loss: 0.0104 - val_mae: 0.0047 - val_rmse: 0.0104
# Epoch 14/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1409 - mae: 0.0558 - rmse: 0.1608 - val_loss: 0.0104 - val_mae: 0.0048 - val_rmse: 0.0104
# Epoch 15/30
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1409 - mae: 0.0562 - rmse: 0.1608 - val_loss: 0.0104 - val_mae: 0.0048 - val_rmse: 0.0104
# Epoch 16/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1408 - mae: 0.0560 - rmse: 0.1607 - val_loss: 0.0104 - val_mae: 0.0048 - val_rmse: 0.0104
# Epoch 17/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1407 - mae: 0.0559 - rmse: 0.1606 - val_loss: 0.0103 - val_mae: 0.0049 - val_rmse: 0.0103
# Epoch 18/30
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1408 - mae: 0.0561 - rmse: 0.1607 - val_loss: 0.0103 - val_mae: 0.0049 - val_rmse: 0.0103
# Epoch 19/30
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1403 - mae: 0.0559 - rmse: 0.1602 - val_loss: 0.0102 - val_mae: 0.0050 - val_rmse: 0.0102
# Epoch 20/30
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1405 - mae: 0.0560 - rmse: 0.1601 - val_loss: 0.0102 - val_mae: 0.0052 - val_rmse: 0.0102
# Epoch 21/30
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1405 - mae: 0.0558 - rmse: 0.1601 - val_loss: 0.0100 - val_mae: 0.0054 - val_rmse: 0.0100
# Epoch 22/30
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1394 - mae: 0.0547 - rmse: 0.1394

# %%
# Recursive Multi-step Forecast
forecasts = forecast(modelTime,normalized_Time, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction(normalized_Time, forecasts, scaler)

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv

with open('predictionsTime.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'Cent.3',forecasts[i],hour[i]
        writer.writerow(d)

# %% [markdown]
# # LSTM - Speed

# %%
# our supervised problem
x, y = to_supervised(normalized_Speed, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)

# %%
# fitting the model
modelSpeed = build_model(TIMESTEPS, FEATURES, name = 'test')
modelSpeed , hist_list, loss_list = compile_and_fit(modelSpeed, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)

# %%
# Recursive Multi-step Forecast
forecastSpeed = forecast(modelSpeed,normalized_Speed, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction_Speed(normalized_Speed, forecastSpeed, scaler)

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv

with open('predictionsSpeed.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'Cent.4',forecasts[i],hour[i]
        writer.writerow(d)

# %% [markdown]
# # LSTM Travel Time + Speed Prediction - Cent.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
traffic = pd.read_csv('../db.csv', parse_dates = ["timeStamp"])
traffic.head(10)
# Out:
#    currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# 0            64             64                 21                  21
# 1            34             43                 49                  39
# 2            64             64                 21                  21
# 3            51             51                 37                  37
# 4            74             74                 21                  21
# 5            33             43                 51                  39
# 6            64             64                 21                  21
# 7            39             50                 49                  38
# 8            74             74                 21                  21
# 9            52             67                 28                  21
#
#   roadName  roadClosure           timeStamp
# 0   N103.1        False 2021-04-26 18:11:34
# 1   N103.0        False 2021-04-27 14:53:37
# 2   N103.1        False 2021-04-27 14:53:49
# 3   N103.2        False 2021-04-27 14:54:00
# 4   N101.0        False 2021-04-27 14:54:12
# 5   N103.0        False 2021-04-27 14:57:10
# 6   N103.1        False 2021-04-27 14:57:22
# 7   N103.2        False 2021-04-27 14:57:33
# 8   N101.0        False 2021-04-27 14:57:45
# 9   N101.1        False 2021-04-27 14:57:57

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278650 entries, 0 to 278649
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   currentSpeed        278650 non-null  int64
#  1   freeFlowSpeed       278650 non-null  int64
#  2   currentTravelTime   278650 non-null  int64
#  3   freeFlowTravelTime  278650 non-null  int64
#  4   roadName            278650 non-null  object
#  5   roadClosure         278650 non-null  bool
#  6   timeStamp           278650 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 13.0+ MB

# %%
print(traffic['roadName'].unique())
# Out:
# ['N103.1' 'N103.0' 'N103.2' 'N101.0' 'N101.1' 'N101.2' 'N101.3' 'N101.4'
#  'N101.5' 'Cent.0' 'Cent.1' 'Cent.2' 'Cent.3' 'Cent.4']

# %% [markdown]
# ### Filter Roads

# %%
traffic = traffic[(traffic['roadName'] == 'Cent.0')]

# %% [markdown]
# ### Drop unwanted columns

# %%
traffic = traffic.drop(columns = ['roadClosure', 'freeFlowTravelTime', 'freeFlowSpeed', 'roadName'])

# %% [markdown]
# ### Remove incomplete days

# %%
tfc = traffic[(traffic['timeStamp'].dt.day != 26) 
                        & (traffic['timeStamp'].dt.day != 27) 
                        & (traffic['timeStamp'].dt.day != 3)
             & (traffic['timeStamp'].dt.day != 14)]

# %% [markdown]
# ### Treat Date and Time

# %%
tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")
# Out:
# <ipython-input-8-7e39a034e481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")

# %%
tfc
# Out:
#         currentSpeed  currentTravelTime   timeStamp
# 6385              10                 54  2021042800
# 6399              10                 54  2021042800
# 6413              10                 54  2021042800
# 6427              10                 54  2021042800
# 6441              10                 54  2021042800
# ...              ...                ...         ...
# 270120            12                 45  2021051323
# 270134            12                 45  2021051323
# 270148            12                 45  2021051323
# 270162            12                 45  2021051323
# 270176            12                 45  2021051323
#
# [17610 rows x 3 columns]

# %%
traffic_by_date = tfc.groupby(['timeStamp'])
traffic_by_date_mean = traffic_by_date.mean()
traffic_by_date_mean
# Out:
#             currentSpeed  currentTravelTime
# timeStamp
# 2021042800     10.000000          54.000000
# 2021042801     10.000000          54.000000
# 2021042802     10.000000          54.000000
# 2021042803     10.000000          54.000000
# 2021042804     10.000000          54.000000
# ...                  ...                ...
# 2021051319      9.769231          55.653846
# 2021051320     10.000000          54.000000
# 2021051321     10.000000          54.000000
# 2021051322      9.921569          57.843137
# 2021051323     10.333333          55.784314
#
# [343 rows x 2 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

normalized_Time = traffic_by_date_mean
normalized_Speed = traffic_by_date_mean

normalized_Time[['currentTravelTime']] = scaler.fit_transform(traffic_by_date_mean[['currentTravelTime']])
normalized_Time = normalized_Time.drop(columns = ['currentSpeed'])
normalized_Time

normalized_Speed[['currentSpeed']] = scaler.fit_transform(traffic_by_date_mean[['currentSpeed']])
normalized_Speed = normalized_Speed.drop(columns = ['currentTravelTime'])
normalized_Speed
# Out:
#             currentSpeed
# timeStamp
# 2021042800      0.354430
# 2021042801      0.354430
# 2021042802      0.354430
# 2021042803      0.354430
# 2021042804      0.354430
# ...                  ...
# 2021051319      0.279942
# 2021051320      0.354430
# 2021051321      0.354430
# 2021051322      0.329114
# 2021051323      0.462025
#
# [343 rows x 1 columns]

# %% [markdown]
# # LSTM - Time

# %%
# 24 hours that make the sequence
TIMESTEPS = 72

# number of features used by the model (using conf. cases to predict conf. cases)
FEATURES = len(normalized_Time.columns)

# number of hours to forecast - we will forecast the next 12 hours
MULTISTEPS = 12

# time series cross validator
CV_SPLITS = 5

EPOCHS = 500

# 24 hours (1 day)
BATCH_SIZE = 72

# %%
# split data into training and validation sets
def split_data(training, percentage = 15):
    train_idx = np.arange(0, int(len(training) * (100 - percentage) / 100))
    val_idx = np.arange(int(len(training) * (100 - percentage) / 100 + 1), len(training))
    
    return train_idx, val_idx

# %%
# Preparing the dataset for the LSTM
def to_supervised(df, timesteps, features = 2):

    data = df.values
    x, y = [], []
    
    # iterate over the training set to create x and y
    dataset_size = len(data)
    
    for curr_pos in range(dataset_size):
        # end of the input sequence is the current position + the number 
        # of timesteps of the input sequence
        input_index = curr_pos + timesteps
        
        # end of the labels correspond to the end of the input sequence + 1
        label_index = input_index + 1
        
        # if we have enough data for this sequence 
        if label_index < dataset_size:
            x.append(data[curr_pos:input_index, :])
            y.append(data[input_index:label_index, 0])
        
    # using np.float32 for GPU performance
    return np.array(x).astype('float32'), np.array(y).astype('float32')


def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))
    

def build_model(timesteps, features, name, h_neurons = 128):
    
    model = tf.keras.models.Sequential(name = name)
    
    model.add(LSTM(h_neurons, return_sequences = True,
                   input_shape = (timesteps, features), 
                   activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(LSTM(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(features, activation = 'tanh'))
    
    return model


# Compiling and fit the model
def compile_and_fit(model, x, y):
    callback = []
    
    callback.append(EarlyStopping(monitor = 'val_loss', min_delta = 0, 
                                  patience = 25, verbose = 0, 
                                  mode = 'auto', restore_best_weights = True))
    
    callback.append(ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, 
                                      patience = 4, verbose = 0,
                                      mode = 'auto', cooldown = 0, 
                                      min_lr = 0.0001))
    
    # compile
    model.compile(loss = rmse, 
                  optimizer = 'RMSprop', 
                  metrics = ['mae', rmse])    
    
    # fit
    hist_list = []
    loss_list = []
    
    # time series cross validator
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    
    for train_index, test_index in tscv.split(x):
        # further split into training and validation sets
        train_idx, val_idx = split_data(train_index, percentage = 15)
        
        x_train, y_train = x[train_idx], y[train_idx]
        x_val, y_val = x[val_idx], y[val_idx]
        #x_test, y_test = x[test_index], y[test_index]
        
        history = model.fit(x_train, y_train, validation_data = (x_val, y_val), 
                            epochs = epochs, batch_size = batch_size, 
                            shuffle = False, callbacks = callback)
        
        plot_learning_curves(history, model_name = model.get_config()['name'])
    
    return model, hist_list, loss_list


# Recursive Multi-step Forecast
def forecast(model, df, scaler, timesteps = 24, 
             multisteps = 6, features = 2, batch_size = 24):
    # getting the last sequence of known value
    input_seq = df[-timesteps:].values
    inp = input_seq
    forecasts = []
    
    # multisteps tells us how many iterations we want to perform, i.e., how many days
    # we want to predict
    for step in range(1, multisteps + 1):
     
        inp = inp.reshape(1, timesteps, features)
        
        yhat = model.predict(inp)
        
        print('yhat', yhat[0][features-1])
        
        yhat_inversed = scaler.inverse_transform(yhat)
        
        print('Transformed yhat', yhat_inversed[0][features-1])
        
        forecasts.append(round(yhat_inversed[0][features-1],4))
    
        inp = np.append(inp[0], yhat[0])
        
        inp = inp[-timesteps*features:]
        
    return forecasts


def plot_prediction(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Travel Time For The Next 12H')
    plt.ylabel('Current Travel Time (min)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()

def plot_prediction_Speed(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Speed For The Next 12H')
    plt.ylabel('Current Speed (KM/H)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()



def plot_learning_curves(history, model_name):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['rmse'], color = 'mediumpurple',linewidth=3)
    plt.plot(history.history['val_rmse'], color = 'purple',linewidth=3)
    plt.title('Model ({}) rmse'.format(model_name))
    plt.ylabel('RMSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color = 'mediumpurple', linewidth=3)
    plt.plot(history.history['val_loss'], color = 'purple', linewidth=3)
    plt.title('Model ({}) loss'.format(model_name))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

# %%
# our supervised problem
x, y = to_supervised(normalized_Time, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (270, 72, 1)
# Training labels shape: (270, 1)

# %%
# fitting the model
modelTime = build_model(TIMESTEPS, FEATURES, name = 'test')
modelTime, hist_list, loss_list = compile_and_fit(modelTime, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 30s 30s/step - loss: 0.8807 - mae: 0.8666 - rmse: 0.8807 - val_loss: 0.3326 - val_mae: 0.2954 - val_rmse: 0.3326
# Epoch 2/500
# 1/1 [==============================] - 0s 392ms/step - loss: 0.3182 - mae: 0.3033 - rmse: 0.3182 - val_loss: 0.4915 - val_mae: 0.3891 - val_rmse: 0.4915
# Epoch 3/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.2548 - mae: 0.1917 - rmse: 0.2548 - val_loss: 0.4876 - val_mae: 0.3836 - val_rmse: 0.4876
# Epoch 4/500
# 1/1 [==============================] - 1s 528ms/step - loss: 0.2490 - mae: 0.1820 - rmse: 0.2490 - val_loss: 0.4700 - val_mae: 0.3588 - val_rmse: 0.4700
# Epoch 5/500
# 1/1 [==============================] - 0s 442ms/step - loss: 0.2310 - mae: 0.1600 - rmse: 0.2310 - val_loss: 0.3872 - val_mae: 0.2343 - val_rmse: 0.3872
# Epoch 6/500
# 1/1 [==============================] - 0s 363ms/step - loss: 0.1822 - mae: 0.0770 - rmse: 0.1822 - val_loss: 0.3799 - val_mae: 0.2253 - val_rmse: 0.3799
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 2/2 [==============================] - 1s 390ms/step - loss: 0.2936 - mae: 0.2647 - rmse: 0.2199 - val_loss: 0.1552 - val_mae: 0.1469 - val_rmse: 0.1552
# Epoch 2/500
# 2/2 [==============================] - 1s 303ms/step - loss: 0.2391 - mae: 0.1869 - rmse: 0.1870 - val_loss: 0.1590 - val_mae: 0.1522 - val_rmse: 0.1590
# Epoch 3/500
# 2/2 [==============================] - 1s 278ms/step - loss: 0.2543 - mae: 0.2071 - rmse: 0.1780 - val_loss: 0.1521 - val_mae: 0.1402 - val_rmse: 0.1521
# Epoch 4/500
# 2/2 [==============================] - 1s 251ms/step - loss: 0.2341 - mae: 0.1805 - rmse: 0.1837 - val_loss: 0.1521 - val_mae: 0.1401 - val_rmse: 0.1521
# Epoch 5/500
# 2/2 [==============================] - 1s 297ms/step - loss: 0.2506 - mae: 0.1975 - rmse: 0.1698 - val_loss: 0.1563 - val_mae: 0.1487 - val_rmse: 0.1563
# Epoch 6/500
# 2/2 [==============================] - 1s 270ms/step - loss: 0.2524 - mae: 0.2015 - rmse: 0.2131 - val_loss: 0.1511 - val_mae: 0.1318 - val_rmse: 0.1511
# Epoch 7/500
# 2/2 [==============================] - 1s 267ms/step - loss: 0.2424 - mae: 0.1872 - rmse: 0.1724 - val_loss: 0.1514 - val_mae: 0.1375 - val_rmse: 0.1514
# Epoch 8/500
# 2/2 [==============================] - 1s 306ms/step - loss: 0.2276 - mae: 0.1824 - rmse: 0.1628 - val_loss: 0.1511 - val_mae: 0.1315 - val_rmse: 0.1511
# Epoch 9/500
# 2/2 [==============================] - 1s 315ms/step - loss: 0.2450 - mae: 0.1864 - rmse: 0.1926 - val_loss: 0.1532 - val_mae: 0.1431 - val_rmse: 0.1532
# Epoch 10/500
# 2/2 [==============================] - 1s 239ms/step - loss: 0.2411 - mae: 0.1900 - rmse: 0.1570 - val_loss: 0.1555 - val_mae: 0.1475 - val_rmse: 0.1555
# Epoch 11/500
# 2/2 [==============================] - 1s 558ms/step - loss: 0.2362 - mae: 0.1940 - rmse: 0.1610 - val_loss: 0.1511 - val_mae: 0.1322 - val_rmse: 0.1511
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.2519 - mae: 0.1846 - rmse: 0.2540 - val_loss: 0.2554 - val_mae: 0.2044 - val_rmse: 0.2554
# Epoch 2/500
# 2/2 [==============================] - 1s 426ms/step - loss: 0.2288 - mae: 0.1691 - rmse: 0.2302 - val_loss: 0.2555 - val_mae: 0.2018 - val_rmse: 0.2555
# Epoch 3/500
# 2/2 [==============================] - 1s 424ms/step - loss: 0.2402 - mae: 0.1688 - rmse: 0.2426 - val_loss: 0.2557 - val_mae: 0.2010 - val_rmse: 0.2557
# Epoch 4/500
# 2/2 [==============================] - 1s 491ms/step - loss: 0.2433 - mae: 0.1687 - rmse: 0.2452 - val_loss: 0.2558 - val_mae: 0.2007 - val_rmse: 0.2558
# Epoch 5/500
# 2/2 [==============================] - 1s 433ms/step - loss: 0.2443 - mae: 0.1704 - rmse: 0.2475 - val_loss: 0.2558 - val_mae: 0.2004 - val_rmse: 0.2558
# Epoch 6/500
# 2/2 [==============================] - 1s 487ms/step - loss: 0.2325 - mae: 0.1621 - rmse: 0.2341 - val_loss: 0.2555 - val_mae: 0.2019 - val_rmse: 0.2555
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 3/3 [==============================] - 1s 443ms/step - loss: 0.2292 - mae: 0.1708 - rmse: 0.2235 - val_loss: 0.1733 - val_mae: 0.1304 - val_rmse: 0.1733
# Epoch 2/500
# 3/3 [==============================] - 1s 371ms/step - loss: 0.2257 - mae: 0.1593 - rmse: 0.2168 - val_loss: 0.1758 - val_mae: 0.1301 - val_rmse: 0.1758
# Epoch 3/500
# 3/3 [==============================] - 1s 390ms/step - loss: 0.2485 - mae: 0.1650 - rmse: 0.2380 - val_loss: 0.1760 - val_mae: 0.1301 - val_rmse: 0.1760
# Epoch 4/500
# 3/3 [==============================] - 1s 386ms/step - loss: 0.2511 - mae: 0.1673 - rmse: 0.2212 - val_loss: 0.1758 - val_mae: 0.1301 - val_rmse: 0.1758
# Epoch 5/500
# 3/3 [==============================] - 1s 364ms/step - loss: 0.2383 - mae: 0.1558 - rmse: 0.2168 - val_loss: 0.1769 - val_mae: 0.1300 - val_rmse: 0.1769
# Epoch 6/500
# 3/3 [==============================] - 2s 560ms/step - loss: 0.2407 - mae: 0.1565 - rmse: 0.2195 - val_loss: 0.1761 - val_mae: 0.1300 - val_rmse: 0.1761
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 3/3 [==============================] - 2s 597ms/step - loss: 0.2327 - mae: 0.1630 - rmse: 0.2300 - val_loss: 0.1494 - val_mae: 0.1227 - val_rmse: 0.1494
# Epoch 2/500
# 3/3 [==============================] - 2s 650ms/step - loss: 0.2380 - mae: 0.1737 - rmse: 0.2353 - val_loss: 0.1500 - val_mae: 0.1256 - val_rmse: 0.1500
# Epoch 3/500
# 3/3 [==============================] - 2s 524ms/step - loss: 0.2325 - mae: 0.1669 - rmse: 0.2312 - val_loss: 0.1505 - val_mae: 0.1276 - val_rmse: 0.1505
# Epoch 4/500
# 3/3 [==============================] - 2s 539ms/step - loss: 0.2424 - mae: 0.1788 - rmse: 0.2408 - val_loss: 0.1500 - val_mae: 0.1257 - val_rmse: 0.1500
# Epoch 5/500
# 3/3 [==============================] - 1s 500ms/step - loss: 0.2292 - mae: 0.1632 - rmse: 0.2267 - val_loss: 0.1531 - val_mae: 0.1341 - val_rmse: 0.1531
# Epoch 6/500
# 3/3 [==============================] - 1s 466ms/step - loss: 0.2336 - mae: 0.1726 - rmse: 0.2312 - val_loss: 0.1512 - val_mae: 0.1297 - val_rmse: 0.1512
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])

# %%
# Recursive Multi-step Forecast
forecasts = forecast(modelTime,normalized_Time, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction(normalized_Time, forecasts, scaler)
# Out:
# yhat -0.6873786
# Transformed yhat 6.772435
# yhat -0.6899936
# Transformed yhat 6.7643332
# yhat -0.6924697
# Transformed yhat 6.7566624
# yhat -0.6948087
# Transformed yhat 6.749416
# yhat -0.69701564
# Transformed yhat 6.742579
# yhat -0.6990967
# Transformed yhat 6.7361317
# yhat -0.7010582
# Transformed yhat 6.730055
# yhat -0.70290685
# Transformed yhat 6.7243276
# yhat -0.7046486
# Transformed yhat 6.7189317
# yhat -0.7062894
# Transformed yhat 6.7138486
# yhat -0.70783484
# Transformed yhat 6.7090607
# yhat -0.70929015
# Transformed yhat 6.704552
# Real data: [ 6.17777546  6.17777546  6.17777546  6.17777546  6.17777546  6.17777546
#   6.21259518 12.          8.18005062  7.32132853  7.24802385  6.40064989
#   7.06659475  7.11061281  6.50214869  6.47282681  6.68283768  6.65975376
#   7.02810979  6.79966702  6.64509282  6.64509282  7.00428577  6.81186098]
# Forecasting values: [6.7724, 6.7643, 6.7567, 6.7494, 6.7426, 6.7361, 6.7301, 6.7243, 6.7189, 6.7138, 6.7091, 6.7046]

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv
'''
with open('predictionsTime.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'Cent.0',forecasts[i],hour[i]
        writer.writerow(d)
    '''
# Out:
# '\nwith open(\'predictionsTime.csv\', mode=\'a\') as csv_file:\n    writer = csv.writer(csv_file, delimiter=\',\', quotechar=\'"\', quoting=csv.QUOTE_MINIMAL)\n    for i in range(12):\n        d = \'Cent.0\',forecasts[i],hour[i]\n        writer.writerow(d)\n    '

# %% [markdown]
# # LSTM - Speed

# %%
# our supervised problem
x, y = to_supervised(normalized_Speed, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (270, 72, 1)
# Training labels shape: (270, 1)

# %%
# fitting the model
modelSpeed = build_model(TIMESTEPS, FEATURES, name = 'test')
modelSpeed , hist_list, loss_list = compile_and_fit(modelSpeed, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 25s 25s/step - loss: 0.6035 - mae: 0.5866 - rmse: 0.6035 - val_loss: 0.5886 - val_mae: 0.3997 - val_rmse: 0.5886
# Epoch 2/500
# 1/1 [==============================] - 1s 515ms/step - loss: 0.2417 - mae: 0.1502 - rmse: 0.2417 - val_loss: 0.4366 - val_mae: 0.3404 - val_rmse: 0.4366
# Epoch 3/500
# 1/1 [==============================] - 1s 702ms/step - loss: 0.4043 - mae: 0.3822 - rmse: 0.4043 - val_loss: 0.5963 - val_mae: 0.4055 - val_rmse: 0.5963
# Epoch 4/500
# 1/1 [==============================] - 1s 657ms/step - loss: 0.2387 - mae: 0.1480 - rmse: 0.2387 - val_loss: 0.4588 - val_mae: 0.2663 - val_rmse: 0.4588
# Epoch 5/500
# 1/1 [==============================] - 1s 655ms/step - loss: 0.2616 - mae: 0.2200 - rmse: 0.2616 - val_loss: 0.6408 - val_mae: 0.4592 - val_rmse: 0.6408
# Epoch 6/500
# 1/1 [==============================] - 1s 628ms/step - loss: 0.2651 - mae: 0.1717 - rmse: 0.2651 - val_loss: 0.4779 - val_mae: 0.2831 - val_rmse: 0.4779
# Epoch 7/500
# 1/1 [==============================] - 1s 554ms/step - loss: 0.2497 - mae: 0.2005 - rmse: 0.2497 - val_loss: 0.4852 - val_mae: 0.2895 - val_rmse: 0.4852
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 2/2 [==============================] - 1s 947ms/step - loss: 0.3449 - mae: 0.3106 - rmse: 0.2309 - val_loss: 0.1870 - val_mae: 0.1737 - val_rmse: 0.1870
# Epoch 2/500
# 2/2 [==============================] - 1s 426ms/step - loss: 0.3345 - mae: 0.2949 - rmse: 0.2220 - val_loss: 0.1839 - val_mae: 0.1698 - val_rmse: 0.1839
# Epoch 3/500
# 2/2 [==============================] - 1s 490ms/step - loss: 0.3341 - mae: 0.2940 - rmse: 0.2295 - val_loss: 0.1821 - val_mae: 0.1671 - val_rmse: 0.1821
# Epoch 4/500
# 2/2 [==============================] - 1s 489ms/step - loss: 0.3358 - mae: 0.2889 - rmse: 0.2380 - val_loss: 0.1810 - val_mae: 0.1653 - val_rmse: 0.1810
# Epoch 5/500
# 2/2 [==============================] - 1s 373ms/step - loss: 0.3273 - mae: 0.2810 - rmse: 0.2407 - val_loss: 0.1804 - val_mae: 0.1640 - val_rmse: 0.1804
# Epoch 6/500
# 2/2 [==============================] - 2s 749ms/step - loss: 0.3169 - mae: 0.2717 - rmse: 0.2223 - val_loss: 0.1795 - val_mae: 0.1623 - val_rmse: 0.1795
# Epoch 7/500
# 2/2 [==============================] - 1s 315ms/step - loss: 0.3154 - mae: 0.2691 - rmse: 0.2347 - val_loss: 0.1792 - val_mae: 0.1614 - val_rmse: 0.1792
# Epoch 8/500
# 2/2 [==============================] - 1s 337ms/step - loss: 0.3222 - mae: 0.2767 - rmse: 0.2372 - val_loss: 0.1789 - val_mae: 0.1607 - val_rmse: 0.1789
# Epoch 9/500
# 2/2 [==============================] - 1s 299ms/step - loss: 0.3143 - mae: 0.2675 - rmse: 0.2286 - val_loss: 0.1782 - val_mae: 0.1586 - val_rmse: 0.1782
# Epoch 10/500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.3068 - mae: 0.2535 - rmse: 0.2194 - val_loss: 0.1780 - val_mae: 0.1576 - val_rmse: 0.1780
# Epoch 11/500
# 2/2 [==============================] - 2s 1s/step - loss: 0.3110 - mae: 0.2588 - rmse: 0.2298 - val_loss: 0.1779 - val_mae: 0.1572 - val_rmse: 0.1779
# Epoch 12/500
# 2/2 [==============================] - 1s 580ms/step - loss: 0.3190 - mae: 0.2673 - rmse: 0.2238 - val_loss: 0.1775 - val_mae: 0.1552 - val_rmse: 0.1775
# Epoch 13/500
# 2/2 [==============================] - 1s 553ms/step - loss: 0.3081 - mae: 0.2534 - rmse: 0.2182 - val_loss: 0.1776 - val_mae: 0.1556 - val_rmse: 0.1776
# Epoch 14/500
# 2/2 [==============================] - 1s 309ms/step - loss: 0.3188 - mae: 0.2651 - rmse: 0.2471 - val_loss: 0.1778 - val_mae: 0.1565 - val_rmse: 0.1778
# Epoch 15/500
# 2/2 [==============================] - 1s 404ms/step - loss: 0.3149 - mae: 0.2578 - rmse: 0.2255 - val_loss: 0.1777 - val_mae: 0.1560 - val_rmse: 0.1777
# Epoch 16/500
# 2/2 [==============================] - 1s 590ms/step - loss: 0.3137 - mae: 0.2572 - rmse: 0.2306 - val_loss: 0.1777 - val_mae: 0.1556 - val_rmse: 0.1777
# Epoch 17/500
# 2/2 [==============================] - 1s 470ms/step - loss: 0.3145 - mae: 0.2610 - rmse: 0.2322 - val_loss: 0.1781 - val_mae: 0.1575 - val_rmse: 0.1781
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 2/2 [==============================] - 1s 917ms/step - loss: 0.3051 - mae: 0.2517 - rmse: 0.3003 - val_loss: 0.3573 - val_mae: 0.3020 - val_rmse: 0.3573
# Epoch 2/500
# 2/2 [==============================] - 1s 633ms/step - loss: 0.3004 - mae: 0.2417 - rmse: 0.2980 - val_loss: 0.3563 - val_mae: 0.2999 - val_rmse: 0.3563
# Epoch 3/500
# 2/2 [==============================] - 1s 594ms/step - loss: 0.2991 - mae: 0.2355 - rmse: 0.2962 - val_loss: 0.3556 - val_mae: 0.2979 - val_rmse: 0.3556
# Epoch 4/500
# 2/2 [==============================] - 1s 540ms/step - loss: 0.3008 - mae: 0.2353 - rmse: 0.2980 - val_loss: 0.3554 - val_mae: 0.2965 - val_rmse: 0.3554
# Epoch 5/500
# 2/2 [==============================] - 1s 592ms/step - loss: 0.2974 - mae: 0.2248 - rmse: 0.2952 - val_loss: 0.3554 - val_mae: 0.2966 - val_rmse: 0.3554
# Epoch 6/500
# 2/2 [==============================] - 1s 592ms/step - loss: 0.2959 - mae: 0.2243 - rmse: 0.2941 - val_loss: 0.3555 - val_mae: 0.2975 - val_rmse: 0.3555
# Epoch 7/500
# 2/2 [==============================] - 1s 624ms/step - loss: 0.2955 - mae: 0.2208 - rmse: 0.2934 - val_loss: 0.3557 - val_mae: 0.2984 - val_rmse: 0.3557
# Epoch 8/500
# 2/2 [==============================] - 1s 559ms/step - loss: 0.2972 - mae: 0.2209 - rmse: 0.2968 - val_loss: 0.3558 - val_mae: 0.2988 - val_rmse: 0.3558
# Epoch 9/500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.2906 - mae: 0.2165 - rmse: 0.2904 - val_loss: 0.3559 - val_mae: 0.2990 - val_rmse: 0.3559
# Epoch 10/500
# 2/2 [==============================] - 1s 477ms/step - loss: 0.2910 - mae: 0.2121 - rmse: 0.2897 - val_loss: 0.3560 - val_mae: 0.2996 - val_rmse: 0.3560
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/500
# 3/3 [==============================] - 1s 468ms/step - loss: 0.3093 - mae: 0.2449 - rmse: 0.3052 - val_loss: 0.2741 - val_mae: 0.2331 - val_rmse: 0.2741
# Epoch 2/500
# 3/3 [==============================] - 1s 444ms/step - loss: 0.2918 - mae: 0.2268 - rmse: 0.2868 - val_loss: 0.2721 - val_mae: 0.2313 - val_rmse: 0.2721
# Epoch 3/500
# 3/3 [==============================] - 1s 429ms/step - loss: 0.2983 - mae: 0.2222 - rmse: 0.2896 - val_loss: 0.2722 - val_mae: 0.2312 - val_rmse: 0.2722
# Epoch 4/500
# 3/3 [==============================] - 1s 435ms/step - loss: 0.2983 - mae: 0.2207 - rmse: 0.2864 - val_loss: 0.2724 - val_mae: 0.2311 - val_rmse: 0.2724
# Epoch 5/500
# 3/3 [==============================] - 1s 430ms/step - loss: 0.3018 - mae: 0.2232 - rmse: 0.2890 - val_loss: 0.2720 - val_mae: 0.2308 - val_rmse: 0.2720
# Epoch 6/500
# 3/3 [==============================] - 1s 382ms/step - loss: 0.3015 - mae: 0.2229 - rmse: 0.2942 - val_loss: 0.2719 - val_mae: 0.2307 - val_rmse: 0.2719
# Epoch 7/500
# 3/3 [==============================] - 1s 373ms/step - loss: 0.3072 - mae: 0.2238 - rmse: 0.2949 - val_loss: 0.2721 - val_mae: 0.2305 - val_rmse: 0.2721
# Epoch 8/500
# 3/3 [==============================] - 1s 455ms/step - loss: 0.3018 - mae: 0.2297 - rmse: 0.2925 - val_loss: 0.2719 - val_mae: 0.2304 - val_rmse: 0.2719
# Epoch 9/500
# 3/3 [==============================] - 1s 395ms/step - loss: 0.3076 - mae: 0.2278 - rmse: 0.2932 - val_loss: 0.2719 - val_mae: 0.2302 - val_rmse: 0.2719
# Epoch 10/500
# 3/3 [==============================] - 1s 437ms/step - loss: 0.3046 - mae: 0.2294 - rmse: 0.2935 - val_loss: 0.2720 - val_mae: 0.2301 - val_rmse: 0.2720
# Epoch 11/500
# 3/3 [==============================] - 1s 407ms/step - loss: 0.2955 - mae: 0.2188 - rmse: 0.2810 - val_loss: 0.2719 - val_mae: 0.2300 - val_rmse: 0.2719
# Epoch 12/500
# 3/3 [==============================] - 1s 389ms/step - loss: 0.3014 - mae: 0.2224 - rmse: 0.2782 - val_loss: 0.2722 - val_mae: 0.2300 - val_rmse: 0.2722
# Epoch 13/500
# 3/3 [==============================] - 2s 550ms/step - loss: 0.3091 - mae: 0.2285 - rmse: 0.2911 - val_loss: 0.2719 - val_mae: 0.2298 - val_rmse: 0.2719
# Epoch 14/500
# 3/3 [==============================] - 2s 507ms/step - loss: 0.2978 - mae: 0.2207 - rmse: 0.2882 - val_loss: 0.2713 - val_mae: 0.2296 - val_rmse: 0.2713
# Epoch 15/500
# 3/3 [==============================] - 2s 524ms/step - loss: 0.3019 - mae: 0.2230 - rmse: 0.2877 - val_loss: 0.2712 - val_mae: 0.2295 - val_rmse: 0.2712
# Epoch 16/500
# 3/3 [==============================] - 2s 654ms/step - loss: 0.3021 - mae: 0.2257 - rmse: 0.2912 - val_loss: 0.2711 - val_mae: 0.2293 - val_rmse: 0.2711
# Epoch 17/500
# 3/3 [==============================] - 2s 508ms/step - loss: 0.2989 - mae: 0.2192 - rmse: 0.2971 - val_loss: 0.2710 - val_mae: 0.2292 - val_rmse: 0.2710
# Epoch 18/500
# 3/3 [==============================] - 1s 433ms/step - loss: 0.3062 - mae: 0.2262 - rmse: 0.2865 - val_loss: 0.2714 - val_mae: 0.2291 - val_rmse: 0.2714
# Epoch 19/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.3110 - mae: 0.2315 - rmse: 0.3004 - val_loss: 0.2713 - val_mae: 0.2290 - val_rmse: 0.2713
# Epoch 20/500
# 3/3 [==============================] - 2s 583ms/step - loss: 0.2995 - mae: 0.2224 - rmse: 0.2879 - val_loss: 0.2710 - val_mae: 0.2288 - val_rmse: 0.2710
# Epoch 21/500
# 3/3 [==============================] - 2s 590ms/step - loss: 0.3040 - mae: 0.2248 - rmse: 0.2894 - val_loss: 0.2711 - val_mae: 0.2287 - val_rmse: 0.2711
# Epoch 22/500
# 3/3 [==============================] - 1s 403ms/step - loss: 0.2980 - mae: 0.2222 - rmse: 0.2817 - val_loss: 0.2708 - val_mae: 0.2286 - val_rmse: 0.2708
# Epoch 23/500
# 3/3 [==============================] - 1s 425ms/step - loss: 0.3016 - mae: 0.2251 - rmse: 0.2843 - val_loss: 0.2705 - val_mae: 0.2285 - val_rmse: 0.2705
# Epoch 24/500
# 3/3 [==============================] - 1s 412ms/step - loss: 0.2994 - mae: 0.2201 - rmse: 0.2902 - val_loss: 0.2703 - val_mae: 0.2283 - val_rmse: 0.2703
# Epoch 25/500
# 3/3 [==============================] - 1s 472ms/step - loss: 0.3011 - mae: 0.2206 - rmse: 0.2889 - val_loss: 0.2699 - val_mae: 0.2280 - val_rmse: 0.2699
# Epoch 26/500
# 3/3 [==============================] - 2s 728ms/step - loss: 0.3020 - mae: 0.2259 - rmse: 0.2897 - val_loss: 0.2700 - val_mae: 0.2279 - val_rmse: 0.2700
# Epoch 27/500
# 3/3 [==============================] - 2s 590ms/step - loss: 0.2919 - mae: 0.2153 - rmse: 0.2819 - val_loss: 0.2701 - val_mae: 0.2278 - val_rmse: 0.2701
# Epoch 28/500
# 3/3 [==============================] - 2s 543ms/step - loss: 0.2990 - mae: 0.2211 - rmse: 0.2873 - val_loss: 0.2701 - val_mae: 0.2277 - val_rmse: 0.2701
# Epoch 29/500
# 3/3 [==============================] - 2s 589ms/step - loss: 0.3055 - mae: 0.2262 - rmse: 0.2938 - val_loss: 0.2700 - val_mae: 0.2276 - val_rmse: 0.2700
# Epoch 30/500
# 3/3 [==============================] - 2s 567ms/step - loss: 0.2996 - mae: 0.2207 - rmse: 0.2818 - val_loss: 0.2699 - val_mae: 0.2274 - val_rmse: 0.2699
# Epoch 31/500
# 3/3 [==============================] - 2s 592ms/step - loss: 0.3048 - mae: 0.2282 - rmse: 0.2887 - val_loss: 0.2697 - val_mae: 0.2272 - val_rmse: 0.2697
# Epoch 32/500
# 3/3 [==============================] - 2s 679ms/step - loss: 0.3070 - mae: 0.2297 - rmse: 0.2953 - val_loss: 0.2692 - val_mae: 0.2269 - val_rmse: 0.2692
# Epoch 33/500
# 3/3 [==============================] - 1s 365ms/step - loss: 0.2977 - mae: 0.2184 - rmse: 0.2861 - val_loss: 0.2688 - val_mae: 0.2269 - val_rmse: 0.2688
# Epoch 34/500
# 3/3 [==============================] - 2s 420ms/step - loss: 0.3060 - mae: 0.2305 - rmse: 0.2973 - val_loss: 0.2688 - val_mae: 0.2268 - val_rmse: 0.2688
# Epoch 35/500
# 3/3 [==============================] - 2s 750ms/step - loss: 0.3032 - mae: 0.2251 - rmse: 0.2849 - val_loss: 0.2687 - val_mae: 0.2266 - val_rmse: 0.2687
# Epoch 36/500
# 3/3 [==============================] - 2s 626ms/step - loss: 0.2903 - mae: 0.2158 - rmse: 0.2804 - val_loss: 0.2687 - val_mae: 0.2263 - val_rmse: 0.2687
# Epoch 37/500
# 3/3 [==============================] - 2s 700ms/step - loss: 0.2981 - mae: 0.2195 - rmse: 0.2845 - val_loss: 0.2685 - val_mae: 0.2264 - val_rmse: 0.2685
# Epoch 38/500
# 3/3 [==============================] - 2s 630ms/step - loss: 0.2959 - mae: 0.2186 - rmse: 0.2884 - val_loss: 0.2683 - val_mae: 0.2264 - val_rmse: 0.2683
# Epoch 39/500
# 3/3 [==============================] - 2s 585ms/step - loss: 0.3038 - mae: 0.2245 - rmse: 0.2756 - val_loss: 0.2686 - val_mae: 0.2259 - val_rmse: 0.2686
# Epoch 40/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.3015 - mae: 0.2275 - rmse: 0.2918 - val_loss: 0.2687 - val_mae: 0.2258 - val_rmse: 0.2687
# Epoch 41/500
# 3/3 [==============================] - 2s 572ms/step - loss: 0.3033 - mae: 0.2225 - rmse: 0.2918 - val_loss: 0.2682 - val_mae: 0.2256 - val_rmse: 0.2682
# Epoch 42/500
# 3/3 [==============================] - 2s 685ms/step - loss: 0.3021 - mae: 0.2232 - rmse: 0.2852 - val_loss: 0.2682 - val_mae: 0.2254 - val_rmse: 0.2682
# Epoch 43/500
# 3/3 [==============================] - 2s 660ms/step - loss: 0.3060 - mae: 0.2269 - rmse: 0.2993 - val_loss: 0.2681 - val_mae: 0.2252 - val_rmse: 0.2681
# Epoch 44/500
# 3/3 [==============================] - 2s 693ms/step - loss: 0.3020 - mae: 0.2230 - rmse: 0.2848 - val_loss: 0.2683 - val_mae: 0.2252 - val_rmse: 0.2683
# Epoch 45/500
# 3/3 [==============================] - 2s 547ms/step - loss: 0.3051 - mae: 0.2264 - rmse: 0.2881 - val_loss: 0.2679 - val_mae: 0.2250 - val_rmse: 0.2679
# Epoch 46/500
# 3/3 [==============================] - 2s 642ms/step - loss: 0.3001 - mae: 0.2229 - rmse: 0.2841 - val_loss: 0.2677 - val_mae: 0.2250 - val_rmse: 0.2677
# Epoch 47/500
# 3/3 [==============================] - 2s 642ms/step - loss: 0.2996 - mae: 0.2217 - rmse: 0.2841 - val_loss: 0.2676 - val_mae: 0.2248 - val_rmse: 0.2676
# Epoch 48/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.2983 - mae: 0.2266 - rmse: 0.2794 - val_loss: 0.2676 - val_mae: 0.2246 - val_rmse: 0.2676
# Epoch 49/500
# 3/3 [==============================] - 1s 414ms/step - loss: 0.2920 - mae: 0.2144 - rmse: 0.2769 - val_loss: 0.2676 - val_mae: 0.2244 - val_rmse: 0.2676
# Epoch 50/500
# 3/3 [==============================] - 2s 505ms/step - loss: 0.2993 - mae: 0.2170 - rmse: 0.2899 - val_loss: 0.2672 - val_mae: 0.2243 - val_rmse: 0.2672
# Epoch 51/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.2964 - mae: 0.2169 - rmse: 0.2812 - val_loss: 0.2673 - val_mae: 0.2240 - val_rmse: 0.2673
# Epoch 52/500
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2902 - mae: 0.2024 - rmse: 0.2902

# %%
# Recursive Multi-step Forecast
forecastSpeed = forecast(modelSpeed,normalized_Speed, scaler, TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction_Speed(normalized_Speed, forecastSpeed, scaler)

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 23:
        newHour =  ts + pd.DateOffset(hour=0)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        
#for i in hour:
    #print(i)

# %%
import csv
'''
with open('predictionsSpeed.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'Cent.0',forecasts[i],hour[i]
        writer.writerow(d)
'''

# %% [markdown]
# # LSTM Travel Time Prediction - N103.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
traffic = pd.read_csv('../db.csv', parse_dates = ["timeStamp"])
traffic.head(10)
# Out:
#    currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# 0            26             43                 65                  39
# 1            64             64                 21                  21
# 2            38             50                 50                  38
# 3            74             74                 21                  21
# 4            34             67                 43                  21
# 5            87             87                 17                  17
# 6            26             44                 65                  38
# 7            64             64                 21                  21
# 8            31             50                 62                  38
# 9            74             74                 21                  21
#
#   roadName  roadClosure           timeStamp
# 0   N103.0        False 2021-04-26 18:00:05
# 1   N103.1        False 2021-04-26 18:00:05
# 2   N103.2        False 2021-04-26 18:00:05
# 3   N101.0        False 2021-04-26 18:00:06
# 4   N101.1        False 2021-04-26 18:00:06
# 5   N101.2        False 2021-04-26 18:00:07
# 6   N103.0        False 2021-04-26 18:06:21
# 7   N103.1        False 2021-04-26 18:06:21
# 8   N103.2        False 2021-04-26 18:06:22
# 9   N101.0        False 2021-04-26 18:06:22

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89524 entries, 0 to 89523
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   currentSpeed        89524 non-null  int64
#  1   freeFlowSpeed       89524 non-null  int64
#  2   currentTravelTime   89524 non-null  int64
#  3   freeFlowTravelTime  89524 non-null  int64
#  4   roadName            89524 non-null  object
#  5   roadClosure         89524 non-null  bool
#  6   timeStamp           89524 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 4.2+ MB

# %%
print(traffic['roadName'].unique())
# Out:
# ['N103.0' 'N103.1' 'N103.2' 'N101.0' 'N101.1' 'N101.2' 'N101.3' 'N101.4'
#  'N101.5' 'Cent.0' 'Cent.1' 'Cent.2' 'Cent.3' 'Cent.4']

# %% [markdown]
# ### Filter Roads

# %%
traffic = traffic[(traffic['roadName'] == 'N103.1')]

# %% [markdown]
# ### Drop unwanted columns

# %%
traffic = traffic.drop(columns = ['roadClosure', 'freeFlowTravelTime', 'freeFlowSpeed', 'currentSpeed', 'roadName'])

# %% [markdown]
# ### Remove incomplete days

# %%
tfc = traffic[(traffic['timeStamp'].dt.day != 26) 
                        & (traffic['timeStamp'].dt.day != 27) 
                        & (traffic['timeStamp'].dt.day != 3)]
tfc.iloc[50:90]
# Out:
#       currentTravelTime           timeStamp
# 7113                 21 2021-04-28 00:58:54
# 7127                 21 2021-04-28 01:00:05
# 7141                 21 2021-04-28 01:01:15
# 7155                 21 2021-04-28 01:02:25
# 7169                 21 2021-04-28 01:03:35
# 7183                 21 2021-04-28 01:04:45
# 7197                 21 2021-04-28 01:05:55
# 7211                 21 2021-04-28 01:07:05
# 7225                 21 2021-04-28 01:08:15
# 7239                 21 2021-04-28 01:09:25
# 7253                 21 2021-04-28 01:10:35
# 7267                 21 2021-04-28 01:11:45
# 7281                 21 2021-04-28 01:12:55
# 7295                 21 2021-04-28 01:14:05
# 7309                 21 2021-04-28 01:15:15
# 7323                 21 2021-04-28 01:16:26
# 7337                 21 2021-04-28 01:17:36
# 7351                 21 2021-04-28 01:18:46
# 7365                 21 2021-04-28 01:19:56
# 7379                 21 2021-04-28 01:21:06
# 7393                 21 2021-04-28 01:22:16
# 7407                 21 2021-04-28 01:23:26
# 7421                 21 2021-04-28 01:24:36
# 7435                 21 2021-04-28 01:25:46
# 7449                 21 2021-04-28 01:26:56
# 7463                 21 2021-04-28 01:28:06
# 7477                 21 2021-04-28 01:29:16
# 7491                 21 2021-04-28 01:30:26
# 7505                 21 2021-04-28 01:31:36
# 7519                 21 2021-04-28 01:32:47
# 7533                 21 2021-04-28 01:33:57
# 7547                 21 2021-04-28 01:35:07
# 7561                 21 2021-04-28 01:36:17
# 7575                 21 2021-04-28 01:37:27
# 7589                 21 2021-04-28 01:38:37
# 7603                 21 2021-04-28 01:39:47
# 7617                 21 2021-04-28 01:40:57
# 7631                 21 2021-04-28 01:42:07
# 7645                 21 2021-04-28 01:43:17
# 7659                 21 2021-04-28 01:44:27

# %% [markdown]
# ### Treat Date and Time

# %%
tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")
# Out:
# <ipython-input-15-7e39a034e481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tfc['timeStamp'] = pd.to_datetime(tfc['timeStamp']).dt.strftime("%Y%m%d%H")

# %%
tfc
# Out:
#        currentTravelTime   timeStamp
# 6413                  21  2021042800
# 6427                  21  2021042800
# 6441                  21  2021042800
# 6455                  21  2021042800
# 6469                  21  2021042800
# ...                  ...         ...
# 80266                 21  2021050223
# 80280                 21  2021050223
# 80294                 21  2021050223
# 80308                 21  2021050223
# 80322                 21  2021050223
#
# [5281 rows x 2 columns]

# %%
traffic_by_date = tfc.groupby(['timeStamp'])
traffic_by_date_mean = traffic_by_date.mean()
traffic_by_date_mean
# Out:
#             currentTravelTime
# timeStamp
# 2021042800               21.0
# 2021042801               21.0
# 2021042802               21.0
# 2021042803               21.0
# 2021042804               21.0
# ...                       ...
# 2021050219               21.0
# 2021050220               21.0
# 2021050221               21.0
# 2021050222               21.0
# 2021050223               21.0
#
# [103 rows x 1 columns]

# %% [markdown]
# ### Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

normalized_traffic = traffic_by_date_mean

normalized_traffic[['currentTravelTime']] = scaler.fit_transform(traffic_by_date_mean[['currentTravelTime']])

# %% [markdown]
# # LSTM

# %%
np.random.seed(420)
tf.random.set_seed(420)
tf.keras.backend.clear_session()

# %%
# 24 hours that make the sequence
TIMESTEPS = 24

# number of features used by the model (using conf. cases to predict conf. cases)
FEATURES = len(normalized_traffic.columns)

# number of days to forecast - we will forecast the next 12 hours
MULTISTEPS = 12

# time series cross validator
CV_SPLITS = 5

EPOCHS = 30

# 24 hours (1 day)
BATCH_SIZE = 24

# %%
# split data into training and validation sets
def split_data(training, percentage = 15):
    train_idx = np.arange(0, int(len(training) * (100 - percentage) / 100))
    val_idx = np.arange(int(len(training) * (100 - percentage) / 100 + 1), len(training))
    
    return train_idx, val_idx

# %%
# Preparing the dataset for the LSTM
def to_supervised(df, timesteps, features = 2):

    data = df.values
    x, y = [], []
    
    # iterate over the training set to create x and y
    dataset_size = len(data)
    
    for curr_pos in range(dataset_size):
        # end of the input sequence is the current position + the number 
        # of timesteps of the input sequence
        input_index = curr_pos + timesteps
        
        # end of the labels correspond to the end of the input sequence + 1
        label_index = input_index + 1
        
        # if we have enough data for this sequence 
        if label_index < dataset_size:
            x.append(data[curr_pos:input_index, :])
            y.append(data[input_index:label_index, 0])
        
    # using np.float32 for GPU performance
    return np.array(x).astype('float32'), np.array(y).astype('float32')


def rmse(y_true, y_pred):
    return tf.keras.backend.sqrt(tf.keras.backend.mean(tf.keras.backend.square(y_pred - y_true)))
    

def build_model(timesteps, features, name, h_neurons = 128):
    
    model = tf.keras.models.Sequential(name = name)
    
    model.add(LSTM(h_neurons, return_sequences = True,
                   input_shape = (timesteps, features), 
                   activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(LSTM(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(h_neurons, activation = 'tanh'))
    model.add(Dropout(0.2))
    
    model.add(Dense(features, activation = 'tanh'))
    
    return model


# Compiling and fit the model
def compile_and_fit(model, x, y, epochs = 25, batch_size = 24, cv_splits = 3):
    callback = []
    
    callback.append(EarlyStopping(monitor = 'val_loss', min_delta = 0, 
                                  patience = 5, verbose = 0, 
                                  mode = 'auto', restore_best_weights = True))
    
    callback.append(ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1, 
                                      patience = 4, verbose = 0,
                                      mode = 'auto', cooldown = 0, 
                                      min_lr = 0.0001))
    
    # compile
    model.compile(loss = rmse, 
                  optimizer = 'adam', 
                  metrics = ['mae', rmse])    
    
    # fit
    hist_list = []
    loss_list = []
    
    # time series cross validator
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    
    for train_index, test_index in tscv.split(x):
        # further split into training and validation sets
        train_idx, val_idx = split_data(train_index, percentage = 15)
        
        x_train, y_train = x[train_idx], y[train_idx]
        x_val, y_val = x[val_idx], y[val_idx]
        #x_test, y_test = x[test_index], y[test_index]
        
        history = model.fit(x_train, y_train, validation_data = (x_val, y_val), 
                            epochs = epochs, batch_size = batch_size, 
                            shuffle = False, callbacks = callback)
        
        plot_learning_curves(history, model_name = model.get_config()['name'])
    
    return model, hist_list, loss_list


# Recursive Multi-step Forecast
def forecast(model, df, scaler, timesteps = 24, 
             multisteps = 6, features = 2, batch_size = 24):
    # getting the last sequence of known value
    input_seq = df[-timesteps:].values
    inp = input_seq
    forecasts = []
    
    # multisteps tells us how many iterations we want to perform, i.e., how many days
    # we want to predict
    for step in range(1, multisteps + 1):
     
        inp = inp.reshape(1, timesteps, features)
        
        yhat = model.predict(inp)
        
        print('yhat', yhat[0][features-1])
        
        yhat_inversed = scaler.inverse_transform(yhat)
        
        print('Transformed yhat', yhat_inversed[0][features-1])
        
        forecasts.append(round(yhat_inversed[0][features-1]))
    
        inp = np.append(inp[0], yhat[0])
        
        inp = inp[-timesteps*features:]
        
    return forecasts


def plot_prediction(data, forecasts, scaler):
    
    d = data.values[-24:, -1]
    d = scaler.inverse_transform([d])[0]
    
    print('Real data:', d)
    print('Forecasting values:', forecasts)
    
    f = []; f.append(round(d[-1])); f.extend(forecasts)
    
    plt.figure(figsize = (8, 6))
    plt.plot(range(len(d)), d, color = 'mediumpurple', label = 'Real', linewidth=3)
    plt.plot(range(len(d) - 1, len(d) + len(f) - 1),
             f, color = 'purple', label = 'predicted', linewidth=3)
    plt.title('Current Travel Time For The Next 12H')
    plt.ylabel('Current Travel Time (min)')
    plt.xlabel('Hours')
    plt.legend()
    plt.show()


def plot_learning_curves(history, model_name):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['rmse'], color = 'mediumpurple',linewidth=3)
    plt.plot(history.history['val_rmse'], color = 'purple',linewidth=3)
    plt.title('Model ({}) rmse'.format(model_name))
    plt.ylabel('RMSE')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color = 'mediumpurple', linewidth=3)
    plt.plot(history.history['val_loss'], color = 'purple', linewidth=3)
    plt.title('Model ({}) loss'.format(model_name))
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.show()

# %%
# our supervised problem
x, y = to_supervised(normalized_traffic, TIMESTEPS, FEATURES)
print('Training shape:', x.shape)
print('Training labels shape:', y.shape)
# Out:
# Training shape: (78, 24, 1)
# Training labels shape: (78, 1)

# %%
# fitting the model
model = build_model(TIMESTEPS, FEATURES, name = 'test')
model, hist_list, loss_list = compile_and_fit(model, x, y, EPOCHS, BATCH_SIZE, CV_SPLITS)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 4s 4s/step - loss: 0.9847 - mae: 0.9840 - rmse: 0.9847 - val_loss: 0.6496 - val_mae: 0.6496 - val_rmse: 0.6496
# Epoch 2/30
# 1/1 [==============================] - 0s 112ms/step - loss: 0.6631 - mae: 0.6612 - rmse: 0.6631 - val_loss: 0.3209 - val_mae: 0.3209 - val_rmse: 0.3209
# Epoch 3/30
# 1/1 [==============================] - 0s 102ms/step - loss: 0.3944 - mae: 0.3899 - rmse: 0.3944 - val_loss: 0.0925 - val_mae: 0.0925 - val_rmse: 0.0925
# Epoch 4/30
# 1/1 [==============================] - 0s 107ms/step - loss: 0.1400 - mae: 0.1352 - rmse: 0.1400 - val_loss: 0.0126 - val_mae: 0.0126 - val_rmse: 0.0126
# Epoch 5/30
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0217 - mae: 0.0204 - rmse: 0.0217 - val_loss: 0.0010 - val_mae: 0.0010 - val_rmse: 0.0010
# Epoch 6/30
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0100 - mae: 0.0047 - rmse: 0.0100 - val_loss: 8.2433e-05 - val_mae: 8.2433e-05 - val_rmse: 8.2433e-05
# Epoch 7/30
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0102 - mae: 0.0032 - rmse: 0.0102 - val_loss: 9.4771e-06 - val_mae: 9.4771e-06 - val_rmse: 9.4771e-06
# Epoch 8/30
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0102 - mae: 0.0032 - rmse: 0.0102 - val_loss: 1.6689e-06 - val_mae: 1.6689e-06 - val_rmse: 1.6689e-06
# Epoch 9/30
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 4.1723e-07 - val_mae: 4.1723e-07 - val_rmse: 4.1723e-07
# Epoch 10/30
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 11/30
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 12/30
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 13/30
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 14/30
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 15/30
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0102 - mae: 0.0031 - rmse: 0.0102 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 1/1 [==============================] - 0s 187ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# Epoch 2/30
# 1/1 [==============================] - 0s 185ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# Epoch 3/30
# 1/1 [==============================] - 0s 137ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# Epoch 4/30
# 1/1 [==============================] - 0s 125ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# Epoch 5/30
# 1/1 [==============================] - 0s 125ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# Epoch 6/30
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1895 - mae: 0.0551 - rmse: 0.1895 - val_loss: 0.3143 - val_mae: 0.2992 - val_rmse: 0.3143
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 2/2 [==============================] - 0s 167ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 2/30
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 3/30
# 2/2 [==============================] - 0s 136ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 4/30
# 2/2 [==============================] - 0s 126ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 5/30
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 6/30
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1766 - mae: 0.0639 - rmse: 0.1555 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 2/2 [==============================] - 0s 138ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# Epoch 2/30
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# Epoch 3/30
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# Epoch 4/30
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# Epoch 5/30
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# Epoch 6/30
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1434 - mae: 0.0480 - rmse: 0.1376 - val_loss: 0.0215 - val_mae: 0.0081 - val_rmse: 0.0215
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])
# Epoch 1/30
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 2/30
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 3/30
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 4/30
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 5/30
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# Epoch 6/30
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1177 - mae: 0.0394 - rmse: 0.0899 - val_loss: 0.0000e+00 - val_mae: 0.0000e+00 - val_rmse: 0.0000e+00
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'lr'])

# %%
# Recursive Multi-step Forecast
forecasts = forecast(model,normalized_traffic, scaler, 
                              TIMESTEPS, MULTISTEPS, FEATURES, BATCH_SIZE)

plot_prediction(normalized_traffic, forecasts, scaler)
# Out:
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# yhat -1.0
# Transformed yhat 21.0
# Real data: [21.         21.         21.         21.         21.         21.
#  21.         21.         21.         21.         21.         21.
#  21.         21.         21.1372549  21.         21.39215686 21.
#  21.         21.         21.         21.         21.         21.        ]
# Forecasting values: [21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21]

# %%
traffic.iloc[6260:6398]
# Out:
#        currentTravelTime           timeStamp
# 87588                 21 2021-05-03 10:05:45
# 87602                 21 2021-05-03 10:06:55
# 87616                 21 2021-05-03 10:08:05
# 87630                 21 2021-05-03 10:09:15
# 87644                 21 2021-05-03 10:10:25
# ...                  ...                 ...
# 89450                 21 2021-05-03 12:41:14
# 89464                 21 2021-05-03 12:42:24
# 89478                 21 2021-05-03 12:43:34
# 89492                 21 2021-05-03 12:44:44
# 89506                 21 2021-05-03 12:45:54
#
# [138 rows x 2 columns]

# %%
hour = []
ts = traffic.iloc[-1]['timeStamp']
tss = pd.to_datetime(ts).hour

for i in range(12):
    if tss == 12:
        newHour =  ts + pd.DateOffset(hour=1)
        day = pd.to_datetime(ts).day
        newDay = newHour + pd.DateOffset(day=day+1)
        tss = 0
        ts = newDay
        hour.append(newDay)
    else: 
        h = pd.to_datetime(ts).hour
        newHour = ts + pd.DateOffset(hour=h+1)
        tss = tss+1
        ts = newHour
        hour.append(newHour)
        print(newHour)
# Out:
# 2021-05-04 02:47:04
# 2021-05-04 03:47:04
# 2021-05-04 04:47:04
# 2021-05-04 05:47:04
# 2021-05-04 06:47:04
# 2021-05-04 07:47:04
# 2021-05-04 08:47:04
# 2021-05-04 09:47:04
# 2021-05-04 10:47:04
# 2021-05-04 11:47:04
# 2021-05-04 12:47:04

# %%
import csv

with open('predictions.csv', mode='a') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for i in range(12):
        d = 'N103.1',forecasts[i],hour[i]
        writer.writerow(d)

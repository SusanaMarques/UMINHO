# %% [markdown]
# # Medical Exam Recommendation Based on Symptoms
#
# Grid Search with Decision Tree Classifier and Random Forest Classifier

# %%
import numpy as np
import pandas as pd
from sklearn import ensemble
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Load Symptom Dataset

# %%
data = pd.read_csv('./Data/final.csv', sep = ',')

# %% [markdown]
# ####  Load Symptom Severity

# %%
severity = pd.read_csv('./Data/Symptom-severity.csv')

# %% [markdown]
# ####  Load Exam Mapping

# %%
mapping = pd.read_csv('./Data/map.csv', sep = ';')

# %% [markdown]
# # Split data for train and test

# %%
symptomCount = 131
testCount = 102

[train,test] = train_test_split(data,random_state=420)
trainA = np.array(train)
trainAX = trainA[:,testCount:]
trainAY = trainA[:,:testCount]

trainX=train.iloc[:,testCount:]
trainY=train.iloc[:,:testCount]
#print(trainY[0:5])

testX=test.iloc[:,testCount:]
testY=test.iloc[:,:testCount]

# %% [markdown]
# # Grid Search

# %%
def realAccuracies(predictions, labels):
    thresh =(predictions.max()+ predictions.min())/2
    predictions[predictions>thresh]=1
    predictions[predictions<=thresh]=0
    
    correctByLine=[]
    for i in range(len(testY)):
        matches = predictions[i]==labels[i]
        correctByLine.append(len(matches[matches==True])/len(matches))
        
    return([len(np.nonzero([x for x in correctByLine if x==1])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.99])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.95])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.90])[0]),
            len(np.nonzero([x for x in correctByLine if x!=1])[0])])


def getRealAcc(clf):
    predicted = clf.predict(testX)
    accs =  realAccuracies(predicted, testY.to_numpy())
    print('')
    print(accs[3]," classified 90% correctly")
    print(accs[2]," classified 95% correctly")
    print(accs[1]," classified 99% correctly")
    print(accs[0]," classified 100% correctly")
    print(accs[4]," classified incorrectly (Not 100%)")

# %%
def gridSearch(model, param_grid, X_train, y_train, X_test, y_test):        
    clf = GridSearchCV(model, param_grid, refit=True, verbose=3)
    clf.fit(X_train,y_train)
    print(clf.best_params_)
    predictions = clf.predict(testX)
    getRealAcc(clf)
    return ;

# %% [markdown]
# # Random Forest Classifier

# %%
grid_params_randomForest = {
    'n_estimators' : [10,20,30,50,100,200,1000],
    'max_depth' : [1, 10, 20, None],
    'bootstrap': [True, False],
}

gridSearch(RandomForestClassifier(), grid_params_randomForest, trainX, trainY, testX, testY)
# Out:
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# [CV] bootstrap=True, max_depth=1, n_estimators=10 ....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=1, n_estimators=10, score=0.027, total=   0.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=10 ....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=1, n_estimators=10, score=0.021, total=   0.2s
# [CV] bootstrap=True, max_depth=1, n_estimators=10 ....................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=1, n_estimators=10, score=0.017, total=   0.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=10 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=10, score=0.028, total=   0.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=10 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=10, score=0.037, total=   0.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=20 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=20, score=0.027, total=   0.5s
# [CV] bootstrap=True, max_depth=1, n_estimators=20 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=20, score=0.021, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=20 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=20, score=0.017, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=20 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=20, score=0.028, total=   0.4s
# [CV] bootstrap=True, max_depth=1, n_estimators=20 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=20, score=0.037, total=   0.4s
# [CV] bootstrap=True, max_depth=1, n_estimators=30 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=30, score=0.027, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=30 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=30, score=0.021, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=30 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=30, score=0.017, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=30 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=30, score=0.028, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=30 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=30, score=0.037, total=   0.6s
# [CV] bootstrap=True, max_depth=1, n_estimators=50 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=50, score=0.027, total=   1.0s
# [CV] bootstrap=True, max_depth=1, n_estimators=50 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=50, score=0.021, total=   1.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=50 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=50, score=0.017, total=   1.0s
# [CV] bootstrap=True, max_depth=1, n_estimators=50 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=50, score=0.028, total=   1.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=50 ....................
# [CV]  bootstrap=True, max_depth=1, n_estimators=50, score=0.037, total=   1.4s
# [CV] bootstrap=True, max_depth=1, n_estimators=100 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=100, score=0.027, total=   2.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=100 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=100, score=0.021, total=   2.5s
# [CV] bootstrap=True, max_depth=1, n_estimators=100 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=100, score=0.017, total=   2.7s
# [CV] bootstrap=True, max_depth=1, n_estimators=100 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=100, score=0.028, total=   2.7s
# [CV] bootstrap=True, max_depth=1, n_estimators=100 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=100, score=0.037, total=   2.2s
# [CV] bootstrap=True, max_depth=1, n_estimators=200 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=200, score=0.027, total=   4.4s
# [CV] bootstrap=True, max_depth=1, n_estimators=200 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=200, score=0.021, total=   4.5s
# [CV] bootstrap=True, max_depth=1, n_estimators=200 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=200, score=0.017, total=   4.5s
# [CV] bootstrap=True, max_depth=1, n_estimators=200 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=200, score=0.028, total=   4.8s
# [CV] bootstrap=True, max_depth=1, n_estimators=200 ...................
# [CV]  bootstrap=True, max_depth=1, n_estimators=200, score=0.037, total=   4.8s
# [CV] bootstrap=True, max_depth=1, n_estimators=1000 ..................
# [CV]  bootstrap=True, max_depth=1, n_estimators=1000, score=0.027, total=  23.5s
# [CV] bootstrap=True, max_depth=1, n_estimators=1000 ..................
# [CV]  bootstrap=True, max_depth=1, n_estimators=1000, score=0.021, total=  24.0s
# [CV] bootstrap=True, max_depth=1, n_estimators=1000 ..................
# [CV]  bootstrap=True, max_depth=1, n_estimators=1000, score=0.017, total=  24.3s
# [CV] bootstrap=True, max_depth=1, n_estimators=1000 ..................
# [CV]  bootstrap=True, max_depth=1, n_estimators=1000, score=0.028, total=  24.4s
# [CV] bootstrap=True, max_depth=1, n_estimators=1000 ..................
# [CV]  bootstrap=True, max_depth=1, n_estimators=1000, score=0.037, total=  24.3s
# [CV] bootstrap=True, max_depth=10, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=10, score=0.554, total=   0.3s
# [CV] bootstrap=True, max_depth=10, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=10, score=0.487, total=   0.4s
# [CV] bootstrap=True, max_depth=10, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=10, score=0.594, total=   0.4s
# [CV] bootstrap=True, max_depth=10, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=10, score=0.509, total=   0.3s
# [CV] bootstrap=True, max_depth=10, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=10, score=0.660, total=   0.3s
# [CV] bootstrap=True, max_depth=10, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=20, score=0.509, total=   0.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=20, score=0.457, total=   0.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=20, score=0.538, total=   0.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=20, score=0.516, total=   0.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=20, score=0.660, total=   0.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=30, score=0.630, total=   0.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=30, score=0.543, total=   0.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=30, score=0.597, total=   0.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=30, score=0.570, total=   1.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=30, score=0.613, total=   0.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=50, score=0.526, total=   1.5s
# [CV] bootstrap=True, max_depth=10, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=50, score=0.544, total=   1.5s
# [CV] bootstrap=True, max_depth=10, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=50, score=0.610, total=   1.5s
# [CV] bootstrap=True, max_depth=10, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=50, score=0.593, total=   1.5s
# [CV] bootstrap=True, max_depth=10, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=10, n_estimators=50, score=0.630, total=   1.5s
# [CV] bootstrap=True, max_depth=10, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=100, score=0.548, total=   3.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=100, score=0.597, total=   3.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=100, score=0.630, total=   4.1s
# [CV] bootstrap=True, max_depth=10, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=100, score=0.546, total=   3.1s
# [CV] bootstrap=True, max_depth=10, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=100, score=0.588, total=   3.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=200, score=0.554, total=   5.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=200, score=0.607, total=   6.1s
# [CV] bootstrap=True, max_depth=10, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=200, score=0.625, total=   6.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=200, score=0.507, total=   5.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=10, n_estimators=200, score=0.611, total=   5.9s
# [CV] bootstrap=True, max_depth=10, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=10, n_estimators=1000, score=0.604, total=  29.4s
# [CV] bootstrap=True, max_depth=10, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=10, n_estimators=1000, score=0.611, total=  29.6s
# [CV] bootstrap=True, max_depth=10, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=10, n_estimators=1000, score=0.571, total=  30.7s
# [CV] bootstrap=True, max_depth=10, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=10, n_estimators=1000, score=0.544, total=  29.0s
# [CV] bootstrap=True, max_depth=10, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=10, n_estimators=1000, score=0.590, total=  29.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=10, score=0.976, total=   0.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=10, score=0.954, total=   0.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=10, score=0.983, total=   0.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=10, score=0.977, total=   0.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=10 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=10, score=0.986, total=   0.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=20, score=0.986, total=   0.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=20, score=0.993, total=   0.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=20, score=0.946, total=   0.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=20, score=0.983, total=   0.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=20 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=20, score=0.994, total=   0.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=30, score=0.989, total=   1.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=30, score=0.993, total=   1.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=30, score=0.969, total=   1.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=30, score=0.959, total=   1.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=30 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=30, score=0.943, total=   1.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=50, score=0.984, total=   1.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=50, score=0.986, total=   1.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=50, score=0.989, total=   1.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=50, score=0.979, total=   1.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=50 ...................
# [CV]  bootstrap=True, max_depth=20, n_estimators=50, score=0.994, total=   1.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.991, total=   3.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.999, total=   3.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.987, total=   3.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.991, total=   3.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.994, total=   3.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=200, score=0.987, total=   6.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=200, score=1.000, total=   6.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=200, score=0.994, total=   7.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=200, score=0.983, total=   6.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=200 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=200, score=0.996, total=   6.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.989, total=  31.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=1.000, total=  31.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.997, total=  31.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=1.000, total=  32.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.996, total=  32.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=10 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=10 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=10 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=10 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=10 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=20 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=20, score=1.000, total=   0.8s
# [CV] bootstrap=True, max_depth=None, n_estimators=20 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=20, score=1.000, total=   0.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=20 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=20, score=1.000, total=   0.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=20 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=20, score=1.000, total=   0.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=20 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=20, score=1.000, total=   0.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=30 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=30, score=1.000, total=   1.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=30 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=30, score=1.000, total=   1.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=30 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=30, score=1.000, total=   1.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=30 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=30, score=1.000, total=   1.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=30 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=30, score=1.000, total=   1.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=50 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=50, score=1.000, total=   1.8s
# [CV] bootstrap=True, max_depth=None, n_estimators=50 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=50, score=1.000, total=   1.8s
# [CV] bootstrap=True, max_depth=None, n_estimators=50 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=50, score=1.000, total=   1.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=50 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=50, score=1.000, total=   1.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=50 .................
# [CV]  bootstrap=True, max_depth=None, n_estimators=50, score=1.000, total=   1.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=100 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=100, score=1.000, total=   3.5s
# [CV] bootstrap=True, max_depth=None, n_estimators=100 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=100, score=1.000, total=   3.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=100 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=100, score=1.000, total=   3.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=100 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=100, score=1.000, total=   3.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=100 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=100, score=1.000, total=   3.5s
# [CV] bootstrap=True, max_depth=None, n_estimators=200 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=200, score=1.000, total=   6.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=200 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=200, score=1.000, total=   6.9s
# [CV] bootstrap=True, max_depth=None, n_estimators=200 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=200, score=1.000, total=   6.9s
# [CV] bootstrap=True, max_depth=None, n_estimators=200 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=200, score=1.000, total=   6.8s
# [CV] bootstrap=True, max_depth=None, n_estimators=200 ................
# [CV]  bootstrap=True, max_depth=None, n_estimators=200, score=1.000, total=   7.0s
# [CV] bootstrap=True, max_depth=None, n_estimators=1000 ...............
# [CV]  bootstrap=True, max_depth=None, n_estimators=1000, score=1.000, total=  36.2s
# [CV] bootstrap=True, max_depth=None, n_estimators=1000 ...............
# [CV]  bootstrap=True, max_depth=None, n_estimators=1000, score=1.000, total=  45.1s
# [CV] bootstrap=True, max_depth=None, n_estimators=1000 ...............
# [CV]  bootstrap=True, max_depth=None, n_estimators=1000, score=1.000, total=  37.4s
# [CV] bootstrap=True, max_depth=None, n_estimators=1000 ...............
# [CV]  bootstrap=True, max_depth=None, n_estimators=1000, score=1.000, total=  41.7s
# [CV] bootstrap=True, max_depth=None, n_estimators=1000 ...............
# [CV]  bootstrap=True, max_depth=None, n_estimators=1000, score=1.000, total=  38.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=10 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=10, score=0.027, total=   0.3s
# [CV] bootstrap=False, max_depth=1, n_estimators=10 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=10, score=0.021, total=   0.3s
# [CV] bootstrap=False, max_depth=1, n_estimators=10 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=10, score=0.017, total=   0.3s
# [CV] bootstrap=False, max_depth=1, n_estimators=10 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=10, score=0.028, total=   0.3s
# [CV] bootstrap=False, max_depth=1, n_estimators=10 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=10, score=0.037, total=   0.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=20 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=20, score=0.027, total=   0.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=20 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=20, score=0.021, total=   0.8s
# [CV] bootstrap=False, max_depth=1, n_estimators=20 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=20, score=0.017, total=   0.6s
# [CV] bootstrap=False, max_depth=1, n_estimators=20 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=20, score=0.028, total=   0.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=20 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=20, score=0.037, total=   0.6s
# [CV] bootstrap=False, max_depth=1, n_estimators=30 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=30, score=0.027, total=   0.9s
# [CV] bootstrap=False, max_depth=1, n_estimators=30 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=30, score=0.021, total=   0.9s
# [CV] bootstrap=False, max_depth=1, n_estimators=30 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=30, score=0.017, total=   1.1s
# [CV] bootstrap=False, max_depth=1, n_estimators=30 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=30, score=0.028, total=   1.2s
# [CV] bootstrap=False, max_depth=1, n_estimators=30 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=30, score=0.037, total=   1.0s
# [CV] bootstrap=False, max_depth=1, n_estimators=50 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=50, score=0.027, total=   1.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=50 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=50, score=0.021, total=   1.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=50 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=50, score=0.017, total=   1.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=50 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=50, score=0.028, total=   2.3s
# [CV] bootstrap=False, max_depth=1, n_estimators=50 ...................
# [CV]  bootstrap=False, max_depth=1, n_estimators=50, score=0.037, total=   2.2s
# [CV] bootstrap=False, max_depth=1, n_estimators=100 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=100, score=0.027, total=   5.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=100 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=100, score=0.021, total=   4.1s
# [CV] bootstrap=False, max_depth=1, n_estimators=100 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=100, score=0.017, total=   3.1s
# [CV] bootstrap=False, max_depth=1, n_estimators=100 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=100, score=0.028, total=   3.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=100 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=100, score=0.037, total=   5.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=200 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=200, score=0.027, total=  10.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=200 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=200, score=0.021, total=   7.8s
# [CV] bootstrap=False, max_depth=1, n_estimators=200 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=200, score=0.017, total=   5.0s
# [CV] bootstrap=False, max_depth=1, n_estimators=200 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=200, score=0.028, total=   5.8s
# [CV] bootstrap=False, max_depth=1, n_estimators=200 ..................
# [CV]  bootstrap=False, max_depth=1, n_estimators=200, score=0.037, total=   5.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=1000 .................
# [CV]  bootstrap=False, max_depth=1, n_estimators=1000, score=0.027, total=  30.1s
# [CV] bootstrap=False, max_depth=1, n_estimators=1000 .................
# [CV]  bootstrap=False, max_depth=1, n_estimators=1000, score=0.021, total=  22.8s
# [CV] bootstrap=False, max_depth=1, n_estimators=1000 .................
# [CV]  bootstrap=False, max_depth=1, n_estimators=1000, score=0.017, total=  22.4s
# [CV] bootstrap=False, max_depth=1, n_estimators=1000 .................
# [CV]  bootstrap=False, max_depth=1, n_estimators=1000, score=0.028, total=  22.7s
# [CV] bootstrap=False, max_depth=1, n_estimators=1000 .................
# [CV]  bootstrap=False, max_depth=1, n_estimators=1000, score=0.037, total=  24.1s
# [CV] bootstrap=False, max_depth=10, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=10, score=0.625, total=   0.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=10, score=0.571, total=   0.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=10, score=0.635, total=   0.3s
# [CV] bootstrap=False, max_depth=10, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=10, score=0.543, total=   0.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=10, score=0.632, total=   0.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=20, score=0.580, total=   0.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=20, score=0.546, total=   0.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=20, score=0.578, total=   0.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=20, score=0.556, total=   0.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=20, score=0.627, total=   0.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=30, score=0.640, total=   1.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=30, score=0.591, total=   1.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=30, score=0.580, total=   1.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=30, score=0.580, total=   1.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=30, score=0.608, total=   1.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=50, score=0.583, total=   1.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=50, score=0.583, total=   1.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=50, score=0.580, total=   1.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=50, score=0.520, total=   1.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=10, n_estimators=50, score=0.607, total=   1.9s
# [CV] bootstrap=False, max_depth=10, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=100, score=0.587, total=   3.3s
# [CV] bootstrap=False, max_depth=10, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=100, score=0.557, total=   4.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=100, score=0.595, total=   4.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=100, score=0.548, total=   6.0s
# [CV] bootstrap=False, max_depth=10, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=100, score=0.585, total=   3.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=200, score=0.621, total=   7.2s
# [CV] bootstrap=False, max_depth=10, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=200, score=0.601, total=   7.1s
# [CV] bootstrap=False, max_depth=10, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=200, score=0.617, total=   6.9s
# [CV] bootstrap=False, max_depth=10, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=200, score=0.563, total=   8.7s
# [CV] bootstrap=False, max_depth=10, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=10, n_estimators=200, score=0.614, total=   8.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=10, n_estimators=1000, score=0.557, total=  40.4s
# [CV] bootstrap=False, max_depth=10, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=10, n_estimators=1000, score=0.568, total=  31.8s
# [CV] bootstrap=False, max_depth=10, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=10, n_estimators=1000, score=0.594, total=  31.9s
# [CV] bootstrap=False, max_depth=10, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=10, n_estimators=1000, score=0.537, total=  31.6s
# [CV] bootstrap=False, max_depth=10, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=10, n_estimators=1000, score=0.594, total=  31.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=10, score=0.983, total=   0.4s
# [CV] bootstrap=False, max_depth=20, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=10, score=0.940, total=   0.4s
# [CV] bootstrap=False, max_depth=20, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=10, score=0.983, total=   0.4s
# [CV] bootstrap=False, max_depth=20, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=10, score=0.972, total=   0.4s
# [CV] bootstrap=False, max_depth=20, n_estimators=10 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=10, score=0.979, total=   0.4s
# [CV] bootstrap=False, max_depth=20, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=20, score=0.967, total=   0.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=20, score=0.966, total=   0.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=20, score=0.923, total=   0.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=20, score=0.979, total=   0.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=20 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=20, score=0.979, total=   0.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=30, score=0.972, total=   1.1s
# [CV] bootstrap=False, max_depth=20, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=30, score=0.960, total=   1.1s
# [CV] bootstrap=False, max_depth=20, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=30, score=0.993, total=   1.2s
# [CV] bootstrap=False, max_depth=20, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=30, score=0.953, total=   1.1s
# [CV] bootstrap=False, max_depth=20, n_estimators=30 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=30, score=0.974, total=   1.1s
# [CV] bootstrap=False, max_depth=20, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=50, score=0.994, total=   1.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=50, score=0.996, total=   1.9s
# [CV] bootstrap=False, max_depth=20, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=50, score=0.987, total=   1.9s
# [CV] bootstrap=False, max_depth=20, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=50, score=0.987, total=   1.8s
# [CV] bootstrap=False, max_depth=20, n_estimators=50 ..................
# [CV]  bootstrap=False, max_depth=20, n_estimators=50, score=0.999, total=   1.9s
# [CV] bootstrap=False, max_depth=20, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=100, score=0.986, total=   3.6s
# [CV] bootstrap=False, max_depth=20, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=100, score=0.993, total=   3.7s
# [CV] bootstrap=False, max_depth=20, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=100, score=0.980, total=   3.7s
# [CV] bootstrap=False, max_depth=20, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=100, score=0.981, total=   3.6s
# [CV] bootstrap=False, max_depth=20, n_estimators=100 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=100, score=1.000, total=   3.7s
# [CV] bootstrap=False, max_depth=20, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=200, score=0.983, total=   7.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=200, score=0.997, total=   7.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=200, score=0.994, total=   7.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=200, score=0.984, total=   7.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=200 .................
# [CV]  bootstrap=False, max_depth=20, n_estimators=200, score=1.000, total=   7.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=20, n_estimators=1000, score=0.983, total=  36.5s
# [CV] bootstrap=False, max_depth=20, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=20, n_estimators=1000, score=1.000, total=  39.3s
# [CV] bootstrap=False, max_depth=20, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=20, n_estimators=1000, score=0.987, total=  36.5s
# [CV] bootstrap=False, max_depth=20, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=20, n_estimators=1000, score=0.989, total=  36.7s
# [CV] bootstrap=False, max_depth=20, n_estimators=1000 ................
# [CV]  bootstrap=False, max_depth=20, n_estimators=1000, score=0.997, total=  37.3s
# [CV] bootstrap=False, max_depth=None, n_estimators=10 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=10 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=10, score=1.000, total=   0.5s
# [CV] bootstrap=False, max_depth=None, n_estimators=10 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=10, score=1.000, total=   0.5s
# [CV] bootstrap=False, max_depth=None, n_estimators=10 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=10 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=10, score=1.000, total=   0.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=20 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=20, score=1.000, total=   0.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=20 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=20, score=1.000, total=   0.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=20 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=20, score=1.000, total=   0.9s
# [CV] bootstrap=False, max_depth=None, n_estimators=20 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=20, score=1.000, total=   0.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=20 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=20, score=1.000, total=   0.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=30 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=30, score=1.000, total=   1.2s
# [CV] bootstrap=False, max_depth=None, n_estimators=30 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=30, score=1.000, total=   1.2s
# [CV] bootstrap=False, max_depth=None, n_estimators=30 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=30, score=1.000, total=   1.2s
# [CV] bootstrap=False, max_depth=None, n_estimators=30 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=30, score=1.000, total=   1.2s
# [CV] bootstrap=False, max_depth=None, n_estimators=30 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=30, score=1.000, total=   1.3s
# [CV] bootstrap=False, max_depth=None, n_estimators=50 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=50, score=1.000, total=   2.6s
# [CV] bootstrap=False, max_depth=None, n_estimators=50 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=50, score=1.000, total=   1.9s
# [CV] bootstrap=False, max_depth=None, n_estimators=50 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=50, score=1.000, total=   2.0s
# [CV] bootstrap=False, max_depth=None, n_estimators=50 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=50, score=1.000, total=   1.9s
# [CV] bootstrap=False, max_depth=None, n_estimators=50 ................
# [CV]  bootstrap=False, max_depth=None, n_estimators=50, score=1.000, total=   2.0s
# [CV] bootstrap=False, max_depth=None, n_estimators=100 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=100, score=1.000, total=   3.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=100 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=100, score=1.000, total=   3.7s
# [CV] bootstrap=False, max_depth=None, n_estimators=100 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=100, score=1.000, total=   3.8s
# [CV] bootstrap=False, max_depth=None, n_estimators=100 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=100, score=1.000, total=   3.7s
# [CV] bootstrap=False, max_depth=None, n_estimators=100 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=100, score=1.000, total=   3.7s
# [CV] bootstrap=False, max_depth=None, n_estimators=200 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=200, score=1.000, total=   7.7s
# [CV] bootstrap=False, max_depth=None, n_estimators=200 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=200, score=1.000, total=   7.5s
# [CV] bootstrap=False, max_depth=None, n_estimators=200 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=200, score=1.000, total=   7.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=200 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=200, score=1.000, total=   7.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=200 ...............
# [CV]  bootstrap=False, max_depth=None, n_estimators=200, score=1.000, total=   7.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=1000 ..............
# [CV]  bootstrap=False, max_depth=None, n_estimators=1000, score=1.000, total=  36.3s
# [CV] bootstrap=False, max_depth=None, n_estimators=1000 ..............
# [CV]  bootstrap=False, max_depth=None, n_estimators=1000, score=1.000, total=  37.1s
# [CV] bootstrap=False, max_depth=None, n_estimators=1000 ..............
# [CV]  bootstrap=False, max_depth=None, n_estimators=1000, score=1.000, total=  37.2s
# [CV] bootstrap=False, max_depth=None, n_estimators=1000 ..............
# [CV]  bootstrap=False, max_depth=None, n_estimators=1000, score=1.000, total=  42.4s
# [CV] bootstrap=False, max_depth=None, n_estimators=1000 ..............

# %% [markdown]
# # Decision Tree Classifier

# %%
grid_params_decisionTree = {
    'criterion' : ['gini', 'entropy'],
    'splitter' : ['best', 'random'],
    'max_depth' : [1, 10, 20, None],
}

gridSearch(DecisionTreeClassifier(), grid_params_decisionTree, trainX, trainY, testX, testY)

# %% [markdown]
# # Estas coisas aqui em baixo são para apagar?

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print ("{}return {}".format(indent, tree_.value[node]))

    recurse(0, 1)
tree_to_code(clf,testX.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-93ce528f9a6f> in <module>
#      22
#      23     recurse(0, 1)
# ---> 24 tree_to_code(clf,testX.columns)
#
# <ipython-input-62-93ce528f9a6f> in tree_to_code(tree, feature_names)
#       2
#       3 def tree_to_code(tree, feature_names):
# ----> 4     tree_ = tree.tree_
#       5     feature_name = [
#       6         feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'tree_'

# %%
z = np.zeros(len(testX.iloc(0)[0]))
#z[114]=1
z[97]=1
oQueAMariaTem = clf.predict([z])[0]
getTests(oQueAMariaTem)
# Out:
# array(['Blood Tests', 'Physical Examination'], dtype=object)

# %%
def getTests(oneHotResults):
    dic = np.array(testY.columns)
    return dic[oneHotResults==1]
# Out:
# array(['Blood Tests', 'Skin biopsy', 'Patch test'], dtype=object)

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

for p in preds:
    print(getTests(p))
# Out:
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Skin biopsy' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Skin biopsy' 'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Physical Examination']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Skin biopsy' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Skin biopsy' 'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests']
# ['Blood Tests']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ...
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Skin biopsy' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination']
# ['Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']

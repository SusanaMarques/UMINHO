# %%
import numpy as np
import pandas as pd
from sklearn import naive_bayes
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load Symptom Dataset

# %%
data = pd.read_csv('./Data/final.csv', sep = ',')

# %% [markdown]
# ####  Load Symptom Severity

# %%
severity = pd.read_csv('./Data/Symptom-severity.csv')

# %% [markdown]
# ####  Load Exam Mapping

# %%
mapping = pd.read_csv('./Data/map.csv', sep = ';')

# %% [markdown]
# # Split data for train and test

# %%
symptomCount = 131
testCount = 102

[train,test] = train_test_split(data,random_state=420)
trainA = np.array(train)
trainAX = trainA[:,testCount:]
trainAY = trainA[:,:testCount]

trainX=train.iloc[:,testCount:]
trainY=train.iloc[:,:testCount]
#print(trainY[0:5])

testX=test.iloc[:,testCount:]
testY=test.iloc[:,:testCount]

# %%
def actualAccuracies( predictions, labels):
    thresh =(predictions.max()+ predictions.min())/2
    predictions[predictions>thresh]=1
    predictions[predictions<=thresh]=0
    
    correctByLine=[]
    for i in range(len(testY)):
        matches = predictions[i]==labels[i]
        correctByLine.append(len(matches[matches==True])/len(matches))
    return([len(np.nonzero([x for x in correctByLine if x==1])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.99])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.95])[0]),
            len(np.nonzero([x for x in correctByLine if x>0.90])[0]),
            len(np.nonzero([x for x in correctByLine if x!=1])[0])
           ])

# %% [markdown]
# # Naive Bayes

# %%
from sklearn import multioutput

clf = multioutput.MultiOutputClassifier(naive_bayes.GaussianNB()).fit(trainX, trainY)

# %%
preds = clf.predict(testX)
accs =  actualAccuracies(preds, testY.to_numpy())

print(accs[3]," classified 90% correctly")
print(accs[2]," classified 95% correctly")
print(accs[1]," classified 99% correctly")
print(accs[0]," classified 100% correctly")
print(accs[4]," classified incorrectly (Not 100%)")
# Out:
# 1170  classified 90% correctly
# 1142  classified 95% correctly
# 1076  classified 99% correctly
# 1011  classified 100% correctly
# 159  classified incorrectly (Not 100%)

# %%
def gridSearch(model, param_grid, modelName, X_train, y_train, X_test, y_test):        
    clf = GridSearchCV(model, param_grid, refit=True, verbose=3)
    clf.fit(X_train,y_train)
    print(clf.best_params_)
    predicted = clf.predict(X_test)
    evaluateModel(modelName, y_test, predicted)
    return ;


def evaluateModel(name, y_test, predicted):
    print("Accuracy:",accuracy_score(y_test,predicted)," : ", name)
    return;

nSteps = 10

grid_params = {
    'estimator__alpha' : np.array(range(nSteps))/nSteps,
    'estimator__fit_prior':[True,False]
}

baseClass = multioutput.MultiOutputClassifier(naive_bayes.BernoulliNB())
print(baseClass.get_params().keys())
gridSearch(baseClass,grid_params,"NBayes",trainX,trainY,testX,testY)
# Out:
# dict_keys(['estimator__alpha', 'estimator__binarize', 'estimator__class_prior', 'estimator__fit_prior', 'estimator', 'n_jobs'])
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] estimator__alpha=0.0, estimator__fit_prior=True .................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  estimator__alpha=0.0, estimator__fit_prior=True, score=0.909, total=   0.6s
# [CV] estimator__alpha=0.0, estimator__fit_prior=True .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [CV]  estimator__alpha=0.0, estimator__fit_prior=True, score=0.944, total=   0.6s
# [CV] estimator__alpha=0.0, estimator__fit_prior=True .................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [CV]  estimator__alpha=0.0, estimator__fit_prior=True, score=0.910, total=   0.6s
# [CV] estimator__alpha=0.0, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=True, score=0.932, total=   0.6s
# [CV] estimator__alpha=0.0, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=True, score=0.925, total=   0.8s
# [CV] estimator__alpha=0.0, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=False, score=0.907, total=   0.8s
# [CV] estimator__alpha=0.0, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=False, score=0.939, total=   0.7s
# [CV] estimator__alpha=0.0, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=False, score=0.913, total=   0.8s
# [CV] estimator__alpha=0.0, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=False, score=0.929, total=   0.7s
# [CV] estimator__alpha=0.0, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.0, estimator__fit_prior=False, score=0.917, total=   0.9s
# [CV] estimator__alpha=0.1, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=True, score=0.909, total=   0.7s
# [CV] estimator__alpha=0.1, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=True, score=0.943, total=   0.6s
# [CV] estimator__alpha=0.1, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=True, score=0.910, total=   0.6s
# [CV] estimator__alpha=0.1, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=True, score=0.929, total=   0.7s
# [CV] estimator__alpha=0.1, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=True, score=0.925, total=   0.7s
# [CV] estimator__alpha=0.1, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=False, score=0.893, total=   0.7s
# [CV] estimator__alpha=0.1, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=False, score=0.925, total=   0.6s
# [CV] estimator__alpha=0.1, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=False, score=0.879, total=   0.6s
# [CV] estimator__alpha=0.1, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=False, score=0.913, total=   0.6s
# [CV] estimator__alpha=0.1, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.1, estimator__fit_prior=False, score=0.907, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=True, score=0.900, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=True, score=0.937, total=   1.0s
# [CV] estimator__alpha=0.2, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=True, score=0.906, total=   0.8s
# [CV] estimator__alpha=0.2, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=True, score=0.917, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=True, score=0.919, total=   0.7s
# [CV] estimator__alpha=0.2, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=False, score=0.850, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=False, score=0.895, total=   0.9s
# [CV] estimator__alpha=0.2, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=False, score=0.863, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=False, score=0.892, total=   0.6s
# [CV] estimator__alpha=0.2, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.2, estimator__fit_prior=False, score=0.896, total=   0.6s
# [CV] estimator__alpha=0.3, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=True, score=0.900, total=   0.8s
# [CV] estimator__alpha=0.3, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=True, score=0.954, total=   0.7s
# [CV] estimator__alpha=0.3, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=True, score=0.906, total=   0.7s
# [CV] estimator__alpha=0.3, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=True, score=0.917, total=   0.9s
# [CV] estimator__alpha=0.3, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=True, score=0.937, total=   0.7s
# [CV] estimator__alpha=0.3, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=False, score=0.829, total=   0.8s
# [CV] estimator__alpha=0.3, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=False, score=0.859, total=   1.1s
# [CV] estimator__alpha=0.3, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=False, score=0.830, total=   0.8s
# [CV] estimator__alpha=0.3, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=False, score=0.868, total=   0.9s
# [CV] estimator__alpha=0.3, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.3, estimator__fit_prior=False, score=0.860, total=   1.1s
# [CV] estimator__alpha=0.4, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=True, score=0.900, total=   1.1s
# [CV] estimator__alpha=0.4, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=True, score=0.953, total=   0.8s
# [CV] estimator__alpha=0.4, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=True, score=0.905, total=   0.7s
# [CV] estimator__alpha=0.4, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=True, score=0.917, total=   0.7s
# [CV] estimator__alpha=0.4, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=True, score=0.934, total=   0.7s
# [CV] estimator__alpha=0.4, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=False, score=0.805, total=   0.9s
# [CV] estimator__alpha=0.4, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=False, score=0.833, total=   0.8s
# [CV] estimator__alpha=0.4, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=False, score=0.822, total=   0.7s
# [CV] estimator__alpha=0.4, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=False, score=0.845, total=   0.9s
# [CV] estimator__alpha=0.4, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.4, estimator__fit_prior=False, score=0.849, total=   0.8s
# [CV] estimator__alpha=0.5, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=True, score=0.897, total=   0.7s
# [CV] estimator__alpha=0.5, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=True, score=0.947, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=True, score=0.897, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=True, score=0.937, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=True, score=0.932, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=False, score=0.771, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=False, score=0.801, total=   0.8s
# [CV] estimator__alpha=0.5, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=False, score=0.805, total=   0.6s
# [CV] estimator__alpha=0.5, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=False, score=0.809, total=   0.9s
# [CV] estimator__alpha=0.5, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.5, estimator__fit_prior=False, score=0.826, total=   0.7s
# [CV] estimator__alpha=0.6, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=True, score=0.876, total=   0.9s
# [CV] estimator__alpha=0.6, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=True, score=0.944, total=   0.8s
# [CV] estimator__alpha=0.6, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=True, score=0.897, total=   1.1s
# [CV] estimator__alpha=0.6, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=True, score=0.930, total=   0.9s
# [CV] estimator__alpha=0.6, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=True, score=0.932, total=   0.7s
# [CV] estimator__alpha=0.6, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=False, score=0.764, total=   0.8s
# [CV] estimator__alpha=0.6, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=False, score=0.789, total=   0.6s
# [CV] estimator__alpha=0.6, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=False, score=0.762, total=   0.7s
# [CV] estimator__alpha=0.6, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=False, score=0.802, total=   0.7s
# [CV] estimator__alpha=0.6, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.6, estimator__fit_prior=False, score=0.812, total=   1.0s
# [CV] estimator__alpha=0.7, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=True, score=0.873, total=   0.8s
# [CV] estimator__alpha=0.7, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=True, score=0.944, total=   0.9s
# [CV] estimator__alpha=0.7, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=True, score=0.897, total=   0.6s
# [CV] estimator__alpha=0.7, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=True, score=0.934, total=   0.8s
# [CV] estimator__alpha=0.7, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=True, score=0.929, total=   0.9s
# [CV] estimator__alpha=0.7, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=False, score=0.742, total=   0.8s
# [CV] estimator__alpha=0.7, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=False, score=0.744, total=   0.6s
# [CV] estimator__alpha=0.7, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=False, score=0.762, total=   1.0s
# [CV] estimator__alpha=0.7, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=False, score=0.778, total=   0.7s
# [CV] estimator__alpha=0.7, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.7, estimator__fit_prior=False, score=0.796, total=   0.8s
# [CV] estimator__alpha=0.8, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=True, score=0.872, total=   0.7s
# [CV] estimator__alpha=0.8, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=True, score=0.915, total=   0.6s
# [CV] estimator__alpha=0.8, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=True, score=0.897, total=   0.7s
# [CV] estimator__alpha=0.8, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=True, score=0.933, total=   0.6s
# [CV] estimator__alpha=0.8, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=True, score=0.923, total=   0.7s
# [CV] estimator__alpha=0.8, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=False, score=0.741, total=   0.7s
# [CV] estimator__alpha=0.8, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=False, score=0.739, total=   0.6s
# [CV] estimator__alpha=0.8, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=False, score=0.749, total=   0.6s
# [CV] estimator__alpha=0.8, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=False, score=0.779, total=   0.8s
# [CV] estimator__alpha=0.8, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.8, estimator__fit_prior=False, score=0.785, total=   0.7s
# [CV] estimator__alpha=0.9, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=True, score=0.870, total=   0.9s
# [CV] estimator__alpha=0.9, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=True, score=0.890, total=   0.6s
# [CV] estimator__alpha=0.9, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=True, score=0.868, total=   0.7s
# [CV] estimator__alpha=0.9, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=True, score=0.933, total=   0.6s
# [CV] estimator__alpha=0.9, estimator__fit_prior=True .................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=True, score=0.923, total=   0.7s
# [CV] estimator__alpha=0.9, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=False, score=0.691, total=   0.6s
# [CV] estimator__alpha=0.9, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=False, score=0.729, total=   0.6s
# [CV] estimator__alpha=0.9, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=False, score=0.741, total=   0.7s
# [CV] estimator__alpha=0.9, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=False, score=0.765, total=   0.6s
# [CV] estimator__alpha=0.9, estimator__fit_prior=False ................
# [CV]  estimator__alpha=0.9, estimator__fit_prior=False, score=0.759, total=   0.7s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.2min finished
# {'estimator__alpha': 0.0, 'estimator__fit_prior': True}
# Accuracy: 0.9264957264957265  :  NBayes

# %%
clf.score(testX,testY)
# Out:
# 1.0

# %%
z = np.zeros(len(testX.iloc(0)[0]))
#z[114]=1
z[97]=1
oQueAMariaTem = clf.predict([z])[0]
getTests(oQueAMariaTem)
# Out:
# array(['Blood Tests', 'Physical Examination'], dtype=object)

# %%
def getTests(oneHotResults):
    dic = np.array(testY.columns)
    return dic[oneHotResults==1]
# Out:
# array(['Blood Tests', 'Skin biopsy', 'Patch test'], dtype=object)

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

for p in preds:
    print(getTests(p))
# Out:
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Skin biopsy' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Skin biopsy' 'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Physical Examination']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests']
# ['Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Skin biopsy' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests']
# ['Blood Tests' 'Physical Examination']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Skin biopsy' 'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Skin biopsy' 'Physical Examination']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests']
# ['Blood Tests']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ...
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Physical Examination']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['Skin biopsy' 'Physical Examination']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test'
#  'Serum aminotransferases (transaminases)' 'Prothrombin time (PTT) test'
#  'Alanine transaminase (ALT) test']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Physical Examination' 'ELISA Test' 'Saliva Test' 'Viral Load Test'
#  'Western Blot']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Blood Tests' 'Physical Examination']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Blood Tests' 'Urine analysis' 'Stool tests' 'Bone marrow test'
#  'Tissue culture']
# ['Blood Tests' 'KOH prep' 'Fungal culture' 'Antigent and Antibody testing'
#  'Sputum test' 'Susceptability testing' 'Gram Strain']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Anti-cyclic citrullinated peptide (anti-CCP)'
#  'Erythrocyte sedimentation rate (ESR)' 'C-reactive protein (CRP)'
#  'Antinuclear antibody (ANA)' 'HLA-B27']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Physical Examination']
# ['Physical Examination']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Physical Examination' 'MRI Scan' 'X-ray']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Urine analysis' 'Urine Culture' 'Susceptibility testing']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Physical Examination' 'Venous duplex scanning'
#  'Trendelenburg test (tourniquet test)']
# ['Skin biopsy' 'Physical Examination']
# ['Blood Tests' 'Skin biopsy' 'Patch test']
# ['Upper gastrointestinal endoscopy' 'Upper gastrointestinal biopsy'
#  'CT scan' 'Helicobacter pylori tests']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests' 'Serum bilirubin test' 'Serum albumin test'
#  'Serum alkaline phosphatase test' 'Liver CT Scan' 'Liver MRI Scan']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Stool tests' 'Stool culture' 'Antigen Tests']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['MRI Scan' 'Electronystagmography (ENG)' 'Videonystagmography (VNG)']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['MRI Scan' 'CT Scan' 'Neck X-ray' 'Myelophagy' 'Electromyography (EMG)']
# ['Blood Tests' 'MRI Scan' 'CT scan' 'Sputum test' 'Biopsy'
#  'Mantoux tuberculin skin test']
# ['Physical Examination']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
# ['Blood Tests' 'Complete blood count (CBC)'
#  'Polymerase chain reaction (PCR)']
# ['Blood Tests' 'Physical Examination' 'Throat Culture' 'Chest X-ray']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'Skin Prick Test (SPT)' 'Intradermal Skin Test'
#  'Physical Examination']
# ['Blood Tests']
# ['Physical Examination' 'Anoscopy' 'Rigid proctosigmoidoscopy'
#  'Colonoscopy' 'Flexible sigmoidoscopy' 'Barium X-ray']
# ['Blood Tests' 'Electrocardiogram (ECG)' 'Echocardiogram' 'Chest X-ray'
#  'Coronary catheterization (angiogram)' 'Cardiac CT' 'Cardiac MRI']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['TSH test' 'T4 test' 'Thyroid scan' 'Thyroid ultrasound'
#  'Radioiodine uptake test' 'Thyroid antibody tests']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Esophagram' 'Esophageal manometry' 'pH monitoring' 'Endoscopy'
#  'Biopsy of upper disgestive system' 'X-ray of upper digestive system']
# ['Blood Tests' 'Serum bilirubin test' 'Biopsy' 'Ultrasound']
# ['Blood Tests' 'Physical Examination' 'Liver Ultrasound' 'Liver Biopsy'
#  'MRI Scan' 'CT Scan']
# ['Blood Tests' 'Physical Examination']
# ['Blood Tests' 'CT scan' 'Chest X-ray' 'Sputum test'
#  'Pleural fluid culture' 'Pulse oximetry']
# ['Blood Tests' 'CT Scan' 'Echocardiogram' 'Brain MRI Scan'
#  'Carotid Ultrasound' 'Cerebral angiogram']
# ['MRI Scan' 'CT scan' 'Sinus X-ray' 'Electroencephalogram' 'Eye Exam']
# ['Dengue NS1 antigen test' 'Serological tests' 'IgG antibody testing'
#  'Nucleic acid amplification tests (NAATs)']
# ['Blood Tests' 'Chest X-ray' 'Spirometry' 'Exhaled nitric oxide test'
#  'Peak flow meter test']
